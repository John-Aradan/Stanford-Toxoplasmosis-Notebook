# %%
""" mount drive to access the dataset"""

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16

def conv_block(input, num_filters):             # part of decoder function only
    x = Conv2D(num_filters, 3, padding="same")(input)  # 3 -> kernalsize
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):   # skip features -> mapping the encoder features 's-1,2,3,4' with decoder
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)  # kernal and stride values as per original UNet
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
"""metric.py"""

import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
"""train.py"""

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau # ModelCheckPoint - save weights;
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision

""" Global parameters """
H = 512
W = 512

def create_dir(path):
    """ Create a directory. """
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(split=0.1): # split as 80-10-10 for train-val-test split
    images = sorted(glob(os.path.join( "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Image", "*.jpg")))                       #
    masks = sorted(glob(os.path.join("/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Mask", "*.jpg")))        # EDIT ACCORDINGLY

    train_x, valid_x = train_test_split(images, test_size=split, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def apply_clahe_img(image):
    # Convert RGB image to LAB color space
    lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)

    # Apply CLAHE to the L channel (Lightness)
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    lab_planes[0] = clahe.apply(lab_planes[0])

    # Merge the enhanced L channel back with the other channels
    lab = cv2.merge(lab_planes)

    # Convert the LAB image back to RGB color space
    enhanced_image = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    return enhanced_image

def apply_clahe_mask(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    image = clahe.apply(image)
    return image

def read_image(path):       # read an image from train_x, or train_y, or... any other data split
    x = cv2.imread(path, cv2.IMREAD_COLOR)      # convert it to 3 channel (if grayscale or else colour only) and
    x = cv2.resize(x, (W, H))                   # resize image to (512,512,3)
    # x = apply_clahe_img(x)
    x = x/255.0                                 # normailise to have value bethween 0 and 1
    x = x.astype(np.float32)                    # convert to numpy float datatype
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    # x = apply_clahe_mask(x)
    x = x/np.max(x)
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)          # convert (512,512) to (512,512,1)
    return x

def tf_parse(x, y):        # this function takes in images x,y
    def _parse(x, y):      # calls read_image and read_mask on the image
        x = x.decode()
        y = y.decode()

        x = read_image(x)
        y = read_mask(y)
        return x, y             # returns as numpy array

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])     # converts numpy array to tensor type
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=8):     # Here X,Y are list containing the images
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.shuffle(buffer_size=200)  # shuffle the dataset
    dataset = dataset.map(tf_parse)     # calls 'tf_parse' function to convert to a tensor
    dataset = dataset.batch(batch)      # create a batch of data
    dataset = dataset.prefetch(4)       # prefect some data in advance to RAM
    return dataset

# %%
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)          # to ensure that randomness is prevented, simmillar results are produced at later implementations
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4      # to limit number of images eveluvated at once to handle GPU limitations
    lr = 1e-5           # learning rate
    num_epochs = 50     # number of iteations
    model_path = os.path.join("files", "model.h5")      # location where model weights from 'ModelCheckpoint' are stored
    csv_path = os.path.join("files", "data.csv")        # location where model csv details from 'CSVLogger' are stored

# %%
    """ Dataset """
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data()

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 47 - 47
# Valid: 6 - 6
# Test: 6 - 6

# %%
    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)   # create train and test dataset out of x_train and y_train
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
    """ Model """

    def build_vgg16_unet(input_shape):     # setup model building function
        """ Input """
        inputs = Input(input_shape)

        """ Pre-trained VGG16 Model """
        vgg16 = VGG16(include_top=False, weights="imagenet", input_tensor=inputs)

        """ Encoder """
        s1 = vgg16.get_layer("block1_conv2").output         ## (512 x 512)  # these labels 'block1_conv2' are from pretrained VGG16 model
        s2 = vgg16.get_layer("block2_conv2").output         ## (256 x 256)
        s3 = vgg16.get_layer("block3_conv3").output         ## (128 x 128)
        s4 = vgg16.get_layer("block4_conv3").output         ## (64 x 64)

        """ Bridge """
        b1 = vgg16.get_layer("block5_conv3").output         ## (32 x 32)

        """ Decoder """
        d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
        d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
        d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
        d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

        """ Output : for binary segmentation"""
        outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

        # if multiclass segmentation: outputs = Conv2D(n, 1, padding="same", ... ) n = number of classes

        model = Model(inputs, outputs, name="VGG16_U-Net")
        return model

    model = build_vgg16_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "VGG16_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 512, 512, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 256, 256, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 256, 256, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 256, 256, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 128, 128, 12  0           ['block2_conv2[0][0]']
#                                 8)
#
#  block3_conv1 (Conv2D)          (None, 128, 128, 25  295168      ['block2_pool[0][0]']
#                                 6)
#
#  block3_conv2 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv1[0][0]']
#                                 6)
#
#  block3_conv3 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv2[0][0]']
#                                 6)
#
#  block3_pool (MaxPooling2D)     (None, 64, 64, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 64, 64, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 32, 32, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  1049088    ['block5_conv3[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv3[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 64, 64, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_1[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'block3_conv3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  activation_2 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_2[0][0]']
#                                 6)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  590080      ['activation_2[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  rmalization)                   6)
#
#  activation_3 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_3[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_3[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 512, 512, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 512, 512, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 1)  65          ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 25,862,337
# Trainable params: 25,858,497
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
    # """Perform Data Augmentation on train and valid sets"""

    # import numpy as np
    # from keras.preprocessing.image import ImageDataGenerator
    # from skimage import io

    # datagen = ImageDataGenerator(
    #         rotation_range=45,     # Random rotation between 0 and 45
    #         width_shift_range=0.2,   # % shift
    #         height_shift_range=0.2,
    #         shear_range=0.2,
    #         zoom_range=0.2,
    #         horizontal_flip=True,
    #         fill_mode='nearest')

    # # Convert dataset objects to numpy arrays
    # train_images = np.array([train_x for train_x, _ in train_dataset])
    # train_labels = np.array([train_y for _, train_y in train_dataset])
    # valid_images = np.array([valid_x for valid_x, _ in valid_dataset])
    # valid_labels = np.array([valid_y for _, valid_y in valid_dataset])

    # # Generate augmented datasets using flow() method
    # augmented_train_dataset = datagen.flow(train_images, train_labels, batch_size=5)
    # augmented_valid_dataset = datagen.flow(valid_images, valid_labels, batch_size=5)

# %%
    callbacks = [                                                                  # defines callbacks
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path)
    ]

    model.fit(                                                                     # fits / trains data
            train_dataset,
            epochs=num_epochs,
            validation_data=valid_dataset,
            callbacks=callbacks
        )
# Out:
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8876 - dice_coef: 0.1111 - iou: 0.0596 - recall: 0.5138 - precision: 0.0713
# Epoch 1: val_loss improved from inf to 0.89696, saving model to files/model.h5
# 12/12 [==============================] - 157s 9s/step - loss: 0.8876 - dice_coef: 0.1111 - iou: 0.0596 - recall: 0.5138 - precision: 0.0713 - val_loss: 0.8970 - val_dice_coef: 0.0876 - val_iou: 0.0464 - val_recall: 0.9825 - val_precision: 0.0571 - lr: 1.0000e-05
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8731 - dice_coef: 0.1262 - iou: 0.0682 - recall: 0.6597 - precision: 0.1024
# Epoch 2: val_loss improved from 0.89696 to 0.89376, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.8731 - dice_coef: 0.1262 - iou: 0.0682 - recall: 0.6597 - precision: 0.1024 - val_loss: 0.8938 - val_dice_coef: 0.1001 - val_iou: 0.0528 - val_recall: 0.9961 - val_precision: 0.0572 - lr: 1.0000e-05
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8571 - dice_coef: 0.1430 - iou: 0.0781 - recall: 0.7779 - precision: 0.1244
# Epoch 3: val_loss improved from 0.89376 to 0.89154, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.8571 - dice_coef: 0.1430 - iou: 0.0781 - recall: 0.7779 - precision: 0.1244 - val_loss: 0.8915 - val_dice_coef: 0.1022 - val_iou: 0.0540 - val_recall: 0.9989 - val_precision: 0.0572 - lr: 1.0000e-05
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8425 - dice_coef: 0.1555 - iou: 0.0855 - recall: 0.8607 - precision: 0.1376
# Epoch 4: val_loss improved from 0.89154 to 0.88792, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.8425 - dice_coef: 0.1555 - iou: 0.0855 - recall: 0.8607 - precision: 0.1376 - val_loss: 0.8879 - val_dice_coef: 0.1083 - val_iou: 0.0573 - val_recall: 0.9997 - val_precision: 0.0572 - lr: 1.0000e-05
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8290 - dice_coef: 0.1696 - iou: 0.0949 - recall: 0.9104 - precision: 0.1506
# Epoch 5: val_loss improved from 0.88792 to 0.88752, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.8290 - dice_coef: 0.1696 - iou: 0.0949 - recall: 0.9104 - precision: 0.1506 - val_loss: 0.8875 - val_dice_coef: 0.1410 - val_iou: 0.0781 - val_recall: 0.9999 - val_precision: 0.0572 - lr: 1.0000e-05
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8087 - dice_coef: 0.1878 - iou: 0.1064 - recall: 0.9596 - precision: 0.1648
# Epoch 6: val_loss improved from 0.88752 to 0.87867, saving model to files/model.h5
# 12/12 [==============================] - 13s 1s/step - loss: 0.8087 - dice_coef: 0.1878 - iou: 0.1064 - recall: 0.9596 - precision: 0.1648 - val_loss: 0.8787 - val_dice_coef: 0.1180 - val_iou: 0.0627 - val_recall: 1.0000 - val_precision: 0.0573 - lr: 1.0000e-05
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7891 - dice_coef: 0.2132 - iou: 0.1220 - recall: 0.9743 - precision: 0.1824
# Epoch 7: val_loss improved from 0.87867 to 0.87395, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7891 - dice_coef: 0.2132 - iou: 0.1220 - recall: 0.9743 - precision: 0.1824 - val_loss: 0.8740 - val_dice_coef: 0.1473 - val_iou: 0.0808 - val_recall: 0.9999 - val_precision: 0.0576 - lr: 1.0000e-05
# Epoch 8/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7760 - dice_coef: 0.2233 - iou: 0.1302 - recall: 0.9794 - precision: 0.2011
# Epoch 8: val_loss improved from 0.87395 to 0.86515, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7760 - dice_coef: 0.2233 - iou: 0.1302 - recall: 0.9794 - precision: 0.2011 - val_loss: 0.8651 - val_dice_coef: 0.1233 - val_iou: 0.0661 - val_recall: 1.0000 - val_precision: 0.0582 - lr: 1.0000e-05
# Epoch 9/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7617 - dice_coef: 0.2376 - iou: 0.1381 - recall: 0.9783 - precision: 0.2288
# Epoch 9: val_loss improved from 0.86515 to 0.85533, saving model to files/model.h5
# 12/12 [==============================] - 13s 1s/step - loss: 0.7617 - dice_coef: 0.2376 - iou: 0.1381 - recall: 0.9783 - precision: 0.2288 - val_loss: 0.8553 - val_dice_coef: 0.1428 - val_iou: 0.0769 - val_recall: 1.0000 - val_precision: 0.0594 - lr: 1.0000e-05
# Epoch 10/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7477 - dice_coef: 0.2494 - iou: 0.1461 - recall: 0.9784 - precision: 0.2452
# Epoch 10: val_loss improved from 0.85533 to 0.85084, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7477 - dice_coef: 0.2494 - iou: 0.1461 - recall: 0.9784 - precision: 0.2452 - val_loss: 0.8508 - val_dice_coef: 0.1474 - val_iou: 0.0796 - val_recall: 0.9996 - val_precision: 0.0652 - lr: 1.0000e-05
# Epoch 11/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7386 - dice_coef: 0.2614 - iou: 0.1555 - recall: 0.9801 - precision: 0.2847
# Epoch 11: val_loss improved from 0.85084 to 0.84462, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7386 - dice_coef: 0.2614 - iou: 0.1555 - recall: 0.9801 - precision: 0.2847 - val_loss: 0.8446 - val_dice_coef: 0.1589 - val_iou: 0.0863 - val_recall: 0.9982 - val_precision: 0.0723 - lr: 1.0000e-05
# Epoch 12/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7322 - dice_coef: 0.2671 - iou: 0.1621 - recall: 0.9814 - precision: 0.3071
# Epoch 12: val_loss improved from 0.84462 to 0.83878, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7322 - dice_coef: 0.2671 - iou: 0.1621 - recall: 0.9814 - precision: 0.3071 - val_loss: 0.8388 - val_dice_coef: 0.1371 - val_iou: 0.0752 - val_recall: 0.9958 - val_precision: 0.0870 - lr: 1.0000e-05
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7120 - dice_coef: 0.2904 - iou: 0.1749 - recall: 0.9841 - precision: 0.3563
# Epoch 13: val_loss improved from 0.83878 to 0.83281, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7120 - dice_coef: 0.2904 - iou: 0.1749 - recall: 0.9841 - precision: 0.3563 - val_loss: 0.8328 - val_dice_coef: 0.1588 - val_iou: 0.0865 - val_recall: 0.9749 - val_precision: 0.1091 - lr: 1.0000e-05
# Epoch 14/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6960 - dice_coef: 0.3064 - iou: 0.1840 - recall: 0.9852 - precision: 0.4082
# Epoch 14: val_loss improved from 0.83281 to 0.81812, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.6960 - dice_coef: 0.3064 - iou: 0.1840 - recall: 0.9852 - precision: 0.4082 - val_loss: 0.8181 - val_dice_coef: 0.1755 - val_iou: 0.0963 - val_recall: 0.9632 - val_precision: 0.1379 - lr: 1.0000e-05
# Epoch 15/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7022 - dice_coef: 0.3004 - iou: 0.1875 - recall: 0.9813 - precision: 0.4263
# Epoch 15: val_loss improved from 0.81812 to 0.80490, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.7022 - dice_coef: 0.3004 - iou: 0.1875 - recall: 0.9813 - precision: 0.4263 - val_loss: 0.8049 - val_dice_coef: 0.1776 - val_iou: 0.0984 - val_recall: 0.9966 - val_precision: 0.1595 - lr: 1.0000e-05
# Epoch 16/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6833 - dice_coef: 0.3199 - iou: 0.1970 - recall: 0.9785 - precision: 0.4427
# Epoch 16: val_loss did not improve from 0.80490
# 12/12 [==============================] - 13s 1s/step - loss: 0.6833 - dice_coef: 0.3199 - iou: 0.1970 - recall: 0.9785 - precision: 0.4427 - val_loss: 0.8099 - val_dice_coef: 0.2161 - val_iou: 0.1233 - val_recall: 0.7814 - val_precision: 0.2438 - lr: 1.0000e-05
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6714 - dice_coef: 0.3266 - iou: 0.2012 - recall: 0.9647 - precision: 0.4991
# Epoch 17: val_loss improved from 0.80490 to 0.76815, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.6714 - dice_coef: 0.3266 - iou: 0.2012 - recall: 0.9647 - precision: 0.4991 - val_loss: 0.7681 - val_dice_coef: 0.2237 - val_iou: 0.1261 - val_recall: 0.9539 - val_precision: 0.2927 - lr: 1.0000e-05
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6547 - dice_coef: 0.3415 - iou: 0.2129 - recall: 0.9899 - precision: 0.5092
# Epoch 18: val_loss did not improve from 0.76815
# 12/12 [==============================] - 13s 1s/step - loss: 0.6547 - dice_coef: 0.3415 - iou: 0.2129 - recall: 0.9899 - precision: 0.5092 - val_loss: 0.7767 - val_dice_coef: 0.2292 - val_iou: 0.1295 - val_recall: 0.7363 - val_precision: 0.4156 - lr: 1.0000e-05
# Epoch 19/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6517 - dice_coef: 0.3486 - iou: 0.2219 - recall: 0.9860 - precision: 0.5486
# Epoch 19: val_loss improved from 0.76815 to 0.74892, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.6517 - dice_coef: 0.3486 - iou: 0.2219 - recall: 0.9860 - precision: 0.5486 - val_loss: 0.7489 - val_dice_coef: 0.2869 - val_iou: 0.1720 - val_recall: 0.8977 - val_precision: 0.4539 - lr: 1.0000e-05
# Epoch 20/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6340 - dice_coef: 0.3670 - iou: 0.2339 - recall: 0.9834 - precision: 0.6201
# Epoch 20: val_loss improved from 0.74892 to 0.72651, saving model to files/model.h5
# 12/12 [==============================] - 13s 1s/step - loss: 0.6340 - dice_coef: 0.3670 - iou: 0.2339 - recall: 0.9834 - precision: 0.6201 - val_loss: 0.7265 - val_dice_coef: 0.2460 - val_iou: 0.1428 - val_recall: 0.8922 - val_precision: 0.5380 - lr: 1.0000e-05
# Epoch 21/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6259 - dice_coef: 0.3742 - iou: 0.2399 - recall: 0.9838 - precision: 0.6348
# Epoch 21: val_loss improved from 0.72651 to 0.71754, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.6259 - dice_coef: 0.3742 - iou: 0.2399 - recall: 0.9838 - precision: 0.6348 - val_loss: 0.7175 - val_dice_coef: 0.2453 - val_iou: 0.1444 - val_recall: 0.8771 - val_precision: 0.5803 - lr: 1.0000e-05
# Epoch 22/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6146 - dice_coef: 0.3883 - iou: 0.2515 - recall: 0.9854 - precision: 0.6797
# Epoch 22: val_loss improved from 0.71754 to 0.69306, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.6146 - dice_coef: 0.3883 - iou: 0.2515 - recall: 0.9854 - precision: 0.6797 - val_loss: 0.6931 - val_dice_coef: 0.2943 - val_iou: 0.1731 - val_recall: 0.8586 - val_precision: 0.6504 - lr: 1.0000e-05
# Epoch 23/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6017 - dice_coef: 0.3933 - iou: 0.2534 - recall: 0.9879 - precision: 0.7038
# Epoch 23: val_loss improved from 0.69306 to 0.67600, saving model to files/model.h5
# 12/12 [==============================] - 13s 1s/step - loss: 0.6017 - dice_coef: 0.3933 - iou: 0.2534 - recall: 0.9879 - precision: 0.7038 - val_loss: 0.6760 - val_dice_coef: 0.2955 - val_iou: 0.1763 - val_recall: 0.8987 - val_precision: 0.6686 - lr: 1.0000e-05
# Epoch 24/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6016 - dice_coef: 0.3943 - iou: 0.2577 - recall: 0.9841 - precision: 0.7150
# Epoch 24: val_loss improved from 0.67600 to 0.65651, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.6016 - dice_coef: 0.3943 - iou: 0.2577 - recall: 0.9841 - precision: 0.7150 - val_loss: 0.6565 - val_dice_coef: 0.3641 - val_iou: 0.2243 - val_recall: 0.9482 - val_precision: 0.6341 - lr: 1.0000e-05
# Epoch 25/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5957 - dice_coef: 0.4046 - iou: 0.2638 - recall: 0.9822 - precision: 0.7230
# Epoch 25: val_loss improved from 0.65651 to 0.64941, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5957 - dice_coef: 0.4046 - iou: 0.2638 - recall: 0.9822 - precision: 0.7230 - val_loss: 0.6494 - val_dice_coef: 0.3491 - val_iou: 0.2115 - val_recall: 0.8663 - val_precision: 0.7124 - lr: 1.0000e-05
# Epoch 26/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5884 - dice_coef: 0.4108 - iou: 0.2702 - recall: 0.9815 - precision: 0.7079
# Epoch 26: val_loss improved from 0.64941 to 0.64233, saving model to files/model.h5
# 12/12 [==============================] - 13s 1s/step - loss: 0.5884 - dice_coef: 0.4108 - iou: 0.2702 - recall: 0.9815 - precision: 0.7079 - val_loss: 0.6423 - val_dice_coef: 0.3801 - val_iou: 0.2368 - val_recall: 0.9841 - val_precision: 0.5756 - lr: 1.0000e-05
# Epoch 27/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5708 - dice_coef: 0.4324 - iou: 0.2852 - recall: 0.9834 - precision: 0.7489
# Epoch 27: val_loss did not improve from 0.64233
# 12/12 [==============================] - 13s 1s/step - loss: 0.5708 - dice_coef: 0.4324 - iou: 0.2852 - recall: 0.9834 - precision: 0.7489 - val_loss: 0.6526 - val_dice_coef: 0.2810 - val_iou: 0.1793 - val_recall: 0.9577 - val_precision: 0.6655 - lr: 1.0000e-05
# Epoch 28/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5564 - dice_coef: 0.4429 - iou: 0.2905 - recall: 0.9893 - precision: 0.7424
# Epoch 28: val_loss improved from 0.64233 to 0.64107, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5564 - dice_coef: 0.4429 - iou: 0.2905 - recall: 0.9893 - precision: 0.7424 - val_loss: 0.6411 - val_dice_coef: 0.3697 - val_iou: 0.2272 - val_recall: 0.8173 - val_precision: 0.7693 - lr: 1.0000e-05
# Epoch 29/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5775 - dice_coef: 0.4293 - iou: 0.2887 - recall: 0.9819 - precision: 0.7424
# Epoch 29: val_loss improved from 0.64107 to 0.63155, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5775 - dice_coef: 0.4293 - iou: 0.2887 - recall: 0.9819 - precision: 0.7424 - val_loss: 0.6316 - val_dice_coef: 0.3235 - val_iou: 0.2007 - val_recall: 0.8615 - val_precision: 0.8083 - lr: 1.0000e-05
# Epoch 30/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5581 - dice_coef: 0.4383 - iou: 0.2905 - recall: 0.9788 - precision: 0.7556
# Epoch 30: val_loss improved from 0.63155 to 0.62215, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5581 - dice_coef: 0.4383 - iou: 0.2905 - recall: 0.9788 - precision: 0.7556 - val_loss: 0.6222 - val_dice_coef: 0.3282 - val_iou: 0.2059 - val_recall: 0.9775 - val_precision: 0.5834 - lr: 1.0000e-05
# Epoch 31/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5519 - dice_coef: 0.4482 - iou: 0.2987 - recall: 0.9844 - precision: 0.8005
# Epoch 31: val_loss improved from 0.62215 to 0.62089, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5519 - dice_coef: 0.4482 - iou: 0.2987 - recall: 0.9844 - precision: 0.8005 - val_loss: 0.6209 - val_dice_coef: 0.3234 - val_iou: 0.2049 - val_recall: 0.9103 - val_precision: 0.7534 - lr: 1.0000e-05
# Epoch 32/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5466 - dice_coef: 0.4570 - iou: 0.3067 - recall: 0.9848 - precision: 0.7835
# Epoch 32: val_loss did not improve from 0.62089
# 12/12 [==============================] - 12s 1s/step - loss: 0.5466 - dice_coef: 0.4570 - iou: 0.3067 - recall: 0.9848 - precision: 0.7835 - val_loss: 0.6331 - val_dice_coef: 0.3133 - val_iou: 0.1966 - val_recall: 0.8118 - val_precision: 0.8327 - lr: 1.0000e-05
# Epoch 33/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5621 - dice_coef: 0.4401 - iou: 0.3004 - recall: 0.9899 - precision: 0.7701
# Epoch 33: val_loss improved from 0.62089 to 0.57954, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5621 - dice_coef: 0.4401 - iou: 0.3004 - recall: 0.9899 - precision: 0.7701 - val_loss: 0.5795 - val_dice_coef: 0.4287 - val_iou: 0.2731 - val_recall: 0.8645 - val_precision: 0.8049 - lr: 1.0000e-05
# Epoch 34/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5553 - dice_coef: 0.4438 - iou: 0.3029 - recall: 0.9869 - precision: 0.7896
# Epoch 34: val_loss did not improve from 0.57954
# 12/12 [==============================] - 12s 997ms/step - loss: 0.5553 - dice_coef: 0.4438 - iou: 0.3029 - recall: 0.9869 - precision: 0.7896 - val_loss: 0.5828 - val_dice_coef: 0.3916 - val_iou: 0.2463 - val_recall: 0.8491 - val_precision: 0.8390 - lr: 1.0000e-05
# Epoch 35/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5497 - dice_coef: 0.4499 - iou: 0.3042 - recall: 0.9807 - precision: 0.8137
# Epoch 35: val_loss improved from 0.57954 to 0.56906, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5497 - dice_coef: 0.4499 - iou: 0.3042 - recall: 0.9807 - precision: 0.8137 - val_loss: 0.5691 - val_dice_coef: 0.4183 - val_iou: 0.2652 - val_recall: 0.9380 - val_precision: 0.6807 - lr: 1.0000e-05
# Epoch 36/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5441 - dice_coef: 0.4562 - iou: 0.3120 - recall: 0.9864 - precision: 0.8273
# Epoch 36: val_loss did not improve from 0.56906
# 12/12 [==============================] - 13s 1s/step - loss: 0.5441 - dice_coef: 0.4562 - iou: 0.3120 - recall: 0.9864 - precision: 0.8273 - val_loss: 0.5704 - val_dice_coef: 0.4375 - val_iou: 0.2803 - val_recall: 0.8448 - val_precision: 0.8416 - lr: 1.0000e-05
# Epoch 37/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5252 - dice_coef: 0.4750 - iou: 0.3229 - recall: 0.9893 - precision: 0.8316
# Epoch 37: val_loss improved from 0.56906 to 0.56859, saving model to files/model.h5
# 12/12 [==============================] - 13s 1s/step - loss: 0.5252 - dice_coef: 0.4750 - iou: 0.3229 - recall: 0.9893 - precision: 0.8316 - val_loss: 0.5686 - val_dice_coef: 0.4493 - val_iou: 0.2913 - val_recall: 0.8492 - val_precision: 0.8433 - lr: 1.0000e-05
# Epoch 38/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5271 - dice_coef: 0.4691 - iou: 0.3206 - recall: 0.9863 - precision: 0.8400
# Epoch 38: val_loss did not improve from 0.56859
# 12/12 [==============================] - 12s 1s/step - loss: 0.5271 - dice_coef: 0.4691 - iou: 0.3206 - recall: 0.9863 - precision: 0.8400 - val_loss: 0.6087 - val_dice_coef: 0.3349 - val_iou: 0.2136 - val_recall: 0.7757 - val_precision: 0.8895 - lr: 1.0000e-05
# Epoch 39/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5337 - dice_coef: 0.4628 - iou: 0.3148 - recall: 0.9820 - precision: 0.8023
# Epoch 39: val_loss did not improve from 0.56859
# 12/12 [==============================] - 13s 1s/step - loss: 0.5337 - dice_coef: 0.4628 - iou: 0.3148 - recall: 0.9820 - precision: 0.8023 - val_loss: 0.6276 - val_dice_coef: 0.4325 - val_iou: 0.2930 - val_recall: 0.7964 - val_precision: 0.8931 - lr: 1.0000e-05
# Epoch 40/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5260 - dice_coef: 0.4713 - iou: 0.3196 - recall: 0.9807 - precision: 0.8301
# Epoch 40: val_loss improved from 0.56859 to 0.55675, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5260 - dice_coef: 0.4713 - iou: 0.3196 - recall: 0.9807 - precision: 0.8301 - val_loss: 0.5568 - val_dice_coef: 0.4112 - val_iou: 0.2634 - val_recall: 0.9421 - val_precision: 0.6915 - lr: 1.0000e-05
# Epoch 41/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5189 - dice_coef: 0.4798 - iou: 0.3285 - recall: 0.9823 - precision: 0.8469
# Epoch 41: val_loss improved from 0.55675 to 0.53557, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5189 - dice_coef: 0.4798 - iou: 0.3285 - recall: 0.9823 - precision: 0.8469 - val_loss: 0.5356 - val_dice_coef: 0.4492 - val_iou: 0.2908 - val_recall: 0.9382 - val_precision: 0.7624 - lr: 1.0000e-05
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5208 - dice_coef: 0.4810 - iou: 0.3309 - recall: 0.9871 - precision: 0.8282
# Epoch 42: val_loss did not improve from 0.53557
# 12/12 [==============================] - 13s 1s/step - loss: 0.5208 - dice_coef: 0.4810 - iou: 0.3309 - recall: 0.9871 - precision: 0.8282 - val_loss: 0.5810 - val_dice_coef: 0.4346 - val_iou: 0.2787 - val_recall: 0.7435 - val_precision: 0.8894 - lr: 1.0000e-05
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5216 - dice_coef: 0.4760 - iou: 0.3275 - recall: 0.9862 - precision: 0.8348
# Epoch 43: val_loss improved from 0.53557 to 0.52049, saving model to files/model.h5
# 12/12 [==============================] - 14s 1s/step - loss: 0.5216 - dice_coef: 0.4760 - iou: 0.3275 - recall: 0.9862 - precision: 0.8348 - val_loss: 0.5205 - val_dice_coef: 0.4707 - val_iou: 0.3082 - val_recall: 0.9255 - val_precision: 0.8209 - lr: 1.0000e-05
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5036 - dice_coef: 0.4995 - iou: 0.3432 - recall: 0.9832 - precision: 0.8574
# Epoch 44: val_loss did not improve from 0.52049
# 12/12 [==============================] - 13s 1s/step - loss: 0.5036 - dice_coef: 0.4995 - iou: 0.3432 - recall: 0.9832 - precision: 0.8574 - val_loss: 0.5881 - val_dice_coef: 0.4748 - val_iou: 0.3316 - val_recall: 0.9377 - val_precision: 0.7550 - lr: 1.0000e-05
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5222 - dice_coef: 0.4767 - iou: 0.3267 - recall: 0.9741 - precision: 0.8511
# Epoch 45: val_loss did not improve from 0.52049
# 12/12 [==============================] - 13s 1s/step - loss: 0.5222 - dice_coef: 0.4767 - iou: 0.3267 - recall: 0.9741 - precision: 0.8511 - val_loss: 0.5660 - val_dice_coef: 0.3730 - val_iou: 0.2450 - val_recall: 0.8929 - val_precision: 0.8339 - lr: 1.0000e-05
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4970 - dice_coef: 0.5000 - iou: 0.3416 - recall: 0.9913 - precision: 0.8199
# Epoch 46: val_loss did not improve from 0.52049
# 12/12 [==============================] - 13s 1s/step - loss: 0.4970 - dice_coef: 0.5000 - iou: 0.3416 - recall: 0.9913 - precision: 0.8199 - val_loss: 0.5618 - val_dice_coef: 0.4216 - val_iou: 0.2684 - val_recall: 0.7985 - val_precision: 0.8828 - lr: 1.0000e-05
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5071 - dice_coef: 0.4936 - iou: 0.3411 - recall: 0.9777 - precision: 0.8493
# Epoch 47: val_loss did not improve from 0.52049
# 12/12 [==============================] - 12s 1s/step - loss: 0.5071 - dice_coef: 0.4936 - iou: 0.3411 - recall: 0.9777 - precision: 0.8493 - val_loss: 0.5877 - val_dice_coef: 0.4748 - val_iou: 0.3314 - val_recall: 0.8999 - val_precision: 0.8494 - lr: 1.0000e-05
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4993 - dice_coef: 0.5015 - iou: 0.3478 - recall: 0.9855 - precision: 0.8755
# Epoch 48: val_loss did not improve from 0.52049
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 12/12 [==============================] - 13s 1s/step - loss: 0.4993 - dice_coef: 0.5015 - iou: 0.3478 - recall: 0.9855 - precision: 0.8755 - val_loss: 0.5288 - val_dice_coef: 0.4887 - val_iou: 0.3249 - val_recall: 0.8971 - val_precision: 0.8002 - lr: 1.0000e-05
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5083 - dice_coef: 0.4896 - iou: 0.3361 - recall: 0.9841 - precision: 0.8573
# Epoch 49: val_loss did not improve from 0.52049
# 12/12 [==============================] - 13s 1s/step - loss: 0.5083 - dice_coef: 0.4896 - iou: 0.3361 - recall: 0.9841 - precision: 0.8573 - val_loss: 0.5234 - val_dice_coef: 0.4831 - val_iou: 0.3187 - val_recall: 0.8894 - val_precision: 0.8170 - lr: 1.0000e-06
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4789 - dice_coef: 0.5213 - iou: 0.3589 - recall: 0.9912 - precision: 0.8661
# Epoch 50: val_loss did not improve from 0.52049
# 12/12 [==============================] - 13s 1s/step - loss: 0.4789 - dice_coef: 0.5213 - iou: 0.3589 - recall: 0.9912 - precision: 0.8661 - val_loss: 0.5415 - val_dice_coef: 0.4260 - val_iou: 0.2756 - val_recall: 0.8655 - val_precision: 0.8513 - lr: 1.0000e-06

# %%
"""eval.py"""

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope      # used to implement additional metrics such as iou, dice_coef, etc

""" Directory for storing files """
create_dir("results")

""" Loading model """# define functions that are externmal to tensorflow
with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
    model = tf.keras.models.load_model("files/model.h5")

for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extracing the image name. """
        image_name = x.split("/")[-1]

        """ Reading the image """       # 'read_image' function
        ori_x = cv2.imread(x, cv2.IMREAD_COLOR)
        ori_x = cv2.resize(ori_x, (W, H))
        x = ori_x/255.0
        x = x.astype(np.float32)
        x = np.expand_dims(x, axis=0)

        """ Reading the mask """        # 'read_mask' function
        ori_y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        ori_y = cv2.resize(ori_y, (W, H))
        ori_y = np.expand_dims(ori_y, axis=-1)  ## (512, 512, 1)
        ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)  ## (512, 512, 3)

        """ Predicting the mask. """
        y_pred = model.predict(x)[0]> 0.5
        y_pred = y_pred.astype(np.int32)        # converting predicted result to integer datatype

        y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)

        """ Saving the predicted mask along with the image and GT """
        save_image_path = f"results/{image_name}"   # location to save image

        sep_line = np.ones((H, 10, 3)) * 255    # a white line with 10 pivel width

        cat_image = np.concatenate([y_pred*255], axis=1)  # original image | original mask | predicted mask [ori_x, sep_line, ori_y, sep_line, y_pred*255]

        cv2.imwrite(save_image_path, cat_image)
