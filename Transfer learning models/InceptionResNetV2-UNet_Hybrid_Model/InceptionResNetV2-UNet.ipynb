# %% [markdown]
# This model had comparitevly better performance when it was run at enochs = 3 and split_size = 0.2 (60-20-20)

# %%
""" mount drive to access the dataset"""

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input, ZeroPadding2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionResNetV2

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
"""metric.py"""

import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
"""train.py"""

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau # ModelCheckPoint - save weights;
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision

""" Global parameters """
H = 512
W = 512

def create_dir(path):
    """ Create a directory. """
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(split=0.2): # split as 60-20-20 for train-val-test split
    images = sorted(glob(os.path.join( "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Data_Augmentation/Images", "*")))                       #
    masks = sorted(glob(os.path.join("/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Data_Augmentation/Masks", "*")))        # EDIT ACCORDINGLY

    train_x, valid_x = train_test_split(images, test_size=split, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split, random_state=42)

    return (train_x, train_y), (valid_x, valid_y)

# %%
def apply_clahe_img(image):
    # Convert RGB image to LAB color space
    lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)

    # Apply CLAHE to the L channel (Lightness)
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    lab_planes[0] = clahe.apply(lab_planes[0])

    # Merge the enhanced L channel back with the other channels
    lab = cv2.merge(lab_planes)

    # Convert the LAB image back to RGB color space
    enhanced_image = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    return enhanced_image

def apply_clahe_mask(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    image = clahe.apply(image)
    return image

def read_image(path):       # read an image from train_x, or train_y, or... any other data split
    x = cv2.imread(path, cv2.IMREAD_COLOR)      # convert it to 3 channel (if grayscale or else colour only) and
    x = cv2.resize(x, (W, H))                   # resize image to (512,512,3)
    # x = apply_clahe_img(x)
    x = x/255.0                                 # normailise to have value bethween 0 and 1
    x = x.astype(np.float32)                    # convert to numpy float datatype
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    # x = apply_clahe_mask(x)
    x = x/np.max(x)
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)          # convert (512,512) to (512,512,1)
    return x

def tf_parse(x, y):        # this function takes in images x,y
    def _parse(x, y):      # calls read_image and read_mask on the image
        x = x.decode()
        y = y.decode()

        x = read_image(x)
        y = read_mask(y)
        return x, y             # returns as numpy array

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])     # converts numpy array to tensor type
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=8):     # Here X,Y are list containing the images
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.shuffle(buffer_size=200)  # shuffle the dataset
    dataset = dataset.map(tf_parse)     # calls 'tf_parse' function to convert to a tensor
    dataset = dataset.batch(batch)      # create a batch of data
    dataset = dataset.prefetch(4)       # prefect some data in advance to RAM
    return dataset

# %%
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)          # to ensure that randomness is prevented, simmillar results are produced at later implementations
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4      # to limit number of images eveluvated at once to handle GPU limitations
    lr = 1e-5           # learning rate
    num_epochs = 20     # number of iteations
    model_path = os.path.join("files", "model.h5")      # location where model weights from 'ModelCheckpoint' are stored
    csv_path = os.path.join("files", "data.csv")        # location where model csv details from 'CSVLogger' are stored

    """ Dataset """
    (train_x, train_y), (valid_x, valid_y) = load_data()

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
# Out:
# Train: 640 - 640
# Valid: 160 - 160

# %%
    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)   # create train and test dataset out of x_train and y_train
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
    """model"""

    def build_inception_resnetv2_unet(input_shape):

      """ Input """
      inputs = Input(input_shape)

      """ Pre-trained InceptionResNetV2 Model """
      encoder = InceptionResNetV2(include_top=False, weights="imagenet", input_tensor=inputs)

      """ Encoder """
      s1 = encoder.get_layer("input_1").output           ## (512 x 512)

      s2 = encoder.get_layer("activation").output        ## (255 x 255)
      s2 = ZeroPadding2D(( (1, 0), (1, 0) ))(s2)         ## (256 x 256)

      s3 = encoder.get_layer("activation_3").output      ## (126 x 126)
      s3 = ZeroPadding2D((1, 1))(s3)                     ## (128 x 128)

      s4 = encoder.get_layer("activation_74").output      ## (61 x 61)
      s4 = ZeroPadding2D(( (2, 1),(2, 1) ))(s4)           ## (64 x 64)

      """ Bridge """
      b1 = encoder.get_layer("activation_161").output     ## (30 x 30)
      b1 = ZeroPadding2D((1, 1))(b1)                      ## (32 x 32)

      """ Decoder """
      d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
      d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
      d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
      d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

      """ Output """
      outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

      model = Model(inputs, outputs, name="InceptionResNetV2_U-Net")
      return model

    model = build_inception_resnetv2_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step
# Model: "InceptionResNetV2_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 255, 255, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 255, 255, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 255, 255, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 253, 253, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 253, 253, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 253, 253, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 253, 253, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 253, 253, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 253, 253, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 126, 126, 64  0           ['activation_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 126, 126, 80  5120        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 126, 126, 80  240        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 126, 126, 80  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 124, 124, 19  138240      ['activation_3[0][0]']
#                                 2)
#
#  batch_normalization_4 (BatchNo  (None, 124, 124, 19  576        ['conv2d_4[0][0]']
#  rmalization)                   2)
#
#  activation_4 (Activation)      (None, 124, 124, 19  0           ['batch_normalization_4[0][0]']
#                                 2)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 61, 61, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 61, 61, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 61, 61, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 61, 61, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 61, 61, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 61, 61, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 61, 61, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 61, 61, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 61, 61, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 61, 61, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 61, 61, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 61, 61, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 61, 61, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 61, 61, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 61, 61, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 61, 61, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 61, 61, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 61, 61, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 61, 61, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 61, 61, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 61, 61, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 61, 61, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 61, 61, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 61, 61, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 61, 61, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 61, 61, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 61, 61, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 61, 61, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 61, 61, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 61, 61, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 61, 61, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (CustomScal  (None, 61, 61, 320)  0          ['mixed_5b[0][0]',
#  eLayer)                                                          'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 61, 61, 320)  0           ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 61, 61, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 61, 61, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 61, 61, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 61, 61, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 61, 61, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 61, 61, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (CustomSc  (None, 61, 61, 320)  0          ['block35_1_ac[0][0]',
#  aleLayer)                                                        'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 61, 61, 320)  0           ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 61, 61, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 61, 61, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 61, 61, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 61, 61, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 61, 61, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 61, 61, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (CustomSc  (None, 61, 61, 320)  0          ['block35_2_ac[0][0]',
#  aleLayer)                                                        'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 61, 61, 320)  0           ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 61, 61, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 61, 61, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 61, 61, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 61, 61, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 61, 61, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 61, 61, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (CustomSc  (None, 61, 61, 320)  0          ['block35_3_ac[0][0]',
#  aleLayer)                                                        'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 61, 61, 320)  0           ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 61, 61, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 61, 61, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 61, 61, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 61, 61, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 61, 61, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 61, 61, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (CustomSc  (None, 61, 61, 320)  0          ['block35_4_ac[0][0]',
#  aleLayer)                                                        'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 61, 61, 320)  0           ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 61, 61, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 61, 61, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 61, 61, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 61, 61, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 61, 61, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 61, 61, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (CustomSc  (None, 61, 61, 320)  0          ['block35_5_ac[0][0]',
#  aleLayer)                                                        'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 61, 61, 320)  0           ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 61, 61, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 61, 61, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 61, 61, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 61, 61, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 61, 61, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 61, 61, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 61, 61, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 61, 61, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 61, 61, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 61, 61, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 61, 61, 320)  41280       ['block35_7_mixed[0][0]']
#
#  custom_scale_layer_6 (CustomSc  (None, 61, 61, 320)  0          ['block35_6_ac[0][0]',
#  aleLayer)                                                        'block35_7_conv[0][0]']
#
# ...
#  batch_normalization_153 (Batch  (None, 30, 30, 128)  384        ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 30, 30, 128)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 30, 30, 160)  143360      ['activation_153[0][0]']
#
#  batch_normalization_154 (Batch  (None, 30, 30, 160)  480        ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 30, 30, 160)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 30, 30, 192)  208896      ['block17_19_ac[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 30, 30, 192)  215040      ['activation_154[0][0]']
#
#  batch_normalization_152 (Batch  (None, 30, 30, 192)  576        ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_155 (Batch  (None, 30, 30, 192)  576        ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 30, 30, 192)  0           ['batch_normalization_152[0][0]']
#
#  activation_155 (Activation)    (None, 30, 30, 192)  0           ['batch_normalization_155[0][0]']
#
#  block17_20_mixed (Concatenate)  (None, 30, 30, 384)  0          ['activation_152[0][0]',
#                                                                   'activation_155[0][0]']
#
#  block17_20_conv (Conv2D)       (None, 30, 30, 1088  418880      ['block17_20_mixed[0][0]']
#                                 )
#
#  custom_scale_layer_29 (CustomS  (None, 30, 30, 1088  0          ['block17_19_ac[0][0]',
#  caleLayer)                     )                                 'block17_20_conv[0][0]']
#
#  block17_20_ac (Activation)     (None, 30, 30, 1088  0           ['custom_scale_layer_29[0][0]']
#                                 )
#
#  conv2d_160 (Conv2D)            (None, 30, 30, 256)  278528      ['block17_20_ac[0][0]']
#
#  batch_normalization_160 (Batch  (None, 30, 30, 256)  768        ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 30, 30, 256)  0           ['batch_normalization_160[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 30, 30, 288)  663552      ['activation_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 30, 30, 288)  864        ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 30, 30, 288)  0           ['batch_normalization_161[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 32, 32, 288)  0          ['activation_161[0][0]']
#  D)
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  590336     ['zero_padding2d_3[0][0]']
#  ose)
#
#  zero_padding2d_2 (ZeroPadding2  (None, 64, 64, 256)  0          ['activation_74[0][0]']
#  D)
#
#  concatenate (Concatenate)      (None, 64, 64, 768)  0           ['conv2d_transpose[0][0]',
#                                                                   'zero_padding2d_2[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 64, 64, 512)  3539456     ['concatenate[0][0]']
#
#  batch_normalization_203 (Batch  (None, 64, 64, 512)  2048       ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 64, 64, 512)  0           ['batch_normalization_203[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 64, 64, 512)  2359808     ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 64, 64, 512)  2048       ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 64, 64, 512)  0           ['batch_normalization_204[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_204[0][0]']
#  spose)                         6)
#
#  zero_padding2d_1 (ZeroPadding2  (None, 128, 128, 80  0          ['activation_3[0][0]']
#  D)                             )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 33  0           ['conv2d_transpose_1[0][0]',
#                                 6)                                'zero_padding2d_1[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 128, 128, 25  774400      ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_205 (Batch  (None, 128, 128, 25  1024       ['conv2d_205[0][0]']
#  Normalization)                 6)
#
#  activation_205 (Activation)    (None, 128, 128, 25  0           ['batch_normalization_205[0][0]']
#                                 6)
#
#  conv2d_206 (Conv2D)            (None, 128, 128, 25  590080      ['activation_205[0][0]']
#                                 6)
#
#  batch_normalization_206 (Batch  (None, 128, 128, 25  1024       ['conv2d_206[0][0]']
#  Normalization)                 6)
#
#  activation_206 (Activation)    (None, 128, 128, 25  0           ['batch_normalization_206[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_206[0][0]']
#  spose)                         8)
#
#  zero_padding2d (ZeroPadding2D)  (None, 256, 256, 32  0          ['activation[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 16  0           ['conv2d_transpose_2[0][0]',
#                                 0)                                'zero_padding2d[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 256, 256, 12  184448      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_207 (Batch  (None, 256, 256, 12  512        ['conv2d_207[0][0]']
#  Normalization)                 8)
#
#  activation_207 (Activation)    (None, 256, 256, 12  0           ['batch_normalization_207[0][0]']
#                                 8)
#
#  conv2d_208 (Conv2D)            (None, 256, 256, 12  147584      ['activation_207[0][0]']
#                                 8)
#
#  batch_normalization_208 (Batch  (None, 256, 256, 12  512        ['conv2d_208[0][0]']
#  Normalization)                 8)
#
#  activation_208 (Activation)    (None, 256, 256, 12  0           ['batch_normalization_208[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_208[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 67  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 512, 512, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_209 (Batch  (None, 512, 512, 64  256        ['conv2d_209[0][0]']
#  Normalization)                 )
#
#  activation_209 (Activation)    (None, 512, 512, 64  0           ['batch_normalization_209[0][0]']
#                                 )
#
#  conv2d_210 (Conv2D)            (None, 512, 512, 64  36928       ['activation_209[0][0]']
#                                 )
#
#  batch_normalization_210 (Batch  (None, 512, 512, 64  256        ['conv2d_210[0][0]']
#  Normalization)                 )
#
#  activation_210 (Activation)    (None, 512, 512, 64  0           ['batch_normalization_210[0][0]']
#                                 )
#
#  conv2d_211 (Conv2D)            (None, 512, 512, 1)  65          ['activation_210[0][0]']
#
# ==================================================================================================
# Total params: 36,793,089
# Trainable params: 36,752,065
# Non-trainable params: 41,024
# __________________________________________________________________________________________________

# %%
    callbacks = [                                                                  # defines callbacks
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path)
    ]

    model.fit(                                                                     # fits / trains data
            train_dataset,
            epochs=num_epochs,
            validation_data=valid_dataset,
            callbacks=callbacks
        )
# Out:
# Epoch 1/20
# <ipython-input-5-a454e1d6dfa1>:35: RuntimeWarning: invalid value encountered in true_divide
#   x = x/np.max(x)
# 160/160 [==============================] - ETA: 0s - loss: 0.7616 - dice_coef: 0.2384 - iou: 0.1412 - recall: 0.8225 - precision: 0.2031
# Epoch 1: val_loss improved from inf to 0.76215, saving model to files/model.h5
# 160/160 [==============================] - 474s 2s/step - loss: 0.7616 - dice_coef: 0.2384 - iou: 0.1412 - recall: 0.8225 - precision: 0.2031 - val_loss: 0.7622 - val_dice_coef: 0.2378 - val_iou: 0.1379 - val_recall: 0.8498 - val_precision: 0.4006 - lr: 1.0000e-05
# Epoch 2/20
# 160/160 [==============================] - ETA: 0s - loss: 0.6099 - dice_coef: 0.3901 - iou: 0.2539 - recall: 0.8924 - precision: 0.4047
# Epoch 2: val_loss improved from 0.76215 to 0.57709, saving model to files/model.h5
# 160/160 [==============================] - 165s 1s/step - loss: 0.6099 - dice_coef: 0.3901 - iou: 0.2539 - recall: 0.8924 - precision: 0.4047 - val_loss: 0.5771 - val_dice_coef: 0.4229 - val_iou: 0.2774 - val_recall: 0.9149 - val_precision: 0.4956 - lr: 1.0000e-05
# Epoch 3/20
# 160/160 [==============================] - ETA: 0s - loss: 0.5176 - dice_coef: 0.4824 - iou: 0.3299 - recall: 0.8837 - precision: 0.5620
# Epoch 3: val_loss improved from 0.57709 to 0.47727, saving model to files/model.h5
# 160/160 [==============================] - 162s 1s/step - loss: 0.5176 - dice_coef: 0.4824 - iou: 0.3299 - recall: 0.8837 - precision: 0.5620 - val_loss: 0.4773 - val_dice_coef: 0.5227 - val_iou: 0.3685 - val_recall: 0.8962 - val_precision: 0.5862 - lr: 1.0000e-05
# Epoch 4/20
# 160/160 [==============================] - ETA: 0s - loss: 0.4796 - dice_coef: 0.5204 - iou: 0.3651 - recall: 0.8871 - precision: 0.6136
# Epoch 4: val_loss improved from 0.47727 to 0.44287, saving model to files/model.h5
# 160/160 [==============================] - 168s 1s/step - loss: 0.4796 - dice_coef: 0.5204 - iou: 0.3651 - recall: 0.8871 - precision: 0.6136 - val_loss: 0.4429 - val_dice_coef: 0.5571 - val_iou: 0.4028 - val_recall: 0.8807 - val_precision: 0.6312 - lr: 1.0000e-05
# Epoch 5/20
# 160/160 [==============================] - ETA: 0s - loss: 0.4592 - dice_coef: 0.5408 - iou: 0.3878 - recall: 0.8993 - precision: 0.6442
# Epoch 5: val_loss improved from 0.44287 to 0.43108, saving model to files/model.h5
# 160/160 [==============================] - 156s 974ms/step - loss: 0.4592 - dice_coef: 0.5408 - iou: 0.3878 - recall: 0.8993 - precision: 0.6442 - val_loss: 0.4311 - val_dice_coef: 0.5689 - val_iou: 0.4098 - val_recall: 0.8627 - val_precision: 0.6572 - lr: 1.0000e-05
# Epoch 6/20
# 160/160 [==============================] - ETA: 0s - loss: 0.4511 - dice_coef: 0.5489 - iou: 0.3965 - recall: 0.8955 - precision: 0.6689
# Epoch 6: val_loss improved from 0.43108 to 0.42593, saving model to files/model.h5
# 160/160 [==============================] - 156s 975ms/step - loss: 0.4511 - dice_coef: 0.5489 - iou: 0.3965 - recall: 0.8955 - precision: 0.6689 - val_loss: 0.4259 - val_dice_coef: 0.5741 - val_iou: 0.4176 - val_recall: 0.8621 - val_precision: 0.6530 - lr: 1.0000e-05
# Epoch 7/20
# 160/160 [==============================] - ETA: 0s - loss: 0.4318 - dice_coef: 0.5682 - iou: 0.4115 - recall: 0.8973 - precision: 0.6834
# Epoch 7: val_loss did not improve from 0.42593
# 160/160 [==============================] - 162s 1s/step - loss: 0.4318 - dice_coef: 0.5682 - iou: 0.4115 - recall: 0.8973 - precision: 0.6834 - val_loss: 0.4328 - val_dice_coef: 0.5672 - val_iou: 0.4110 - val_recall: 0.8640 - val_precision: 0.6625 - lr: 1.0000e-05
# Epoch 8/20
# 160/160 [==============================] - ETA: 0s - loss: 0.4169 - dice_coef: 0.5831 - iou: 0.4264 - recall: 0.9010 - precision: 0.6984
# Epoch 8: val_loss improved from 0.42593 to 0.40786, saving model to files/model.h5
# 160/160 [==============================] - 159s 993ms/step - loss: 0.4169 - dice_coef: 0.5831 - iou: 0.4264 - recall: 0.9010 - precision: 0.6984 - val_loss: 0.4079 - val_dice_coef: 0.5921 - val_iou: 0.4343 - val_recall: 0.8400 - val_precision: 0.6832 - lr: 1.0000e-05
# Epoch 9/20
# 160/160 [==============================] - ETA: 0s - loss: 0.4126 - dice_coef: 0.5874 - iou: 0.4330 - recall: 0.9101 - precision: 0.7051
# Epoch 9: val_loss did not improve from 0.40786
# 160/160 [==============================] - 153s 955ms/step - loss: 0.4126 - dice_coef: 0.5874 - iou: 0.4330 - recall: 0.9101 - precision: 0.7051 - val_loss: 0.4189 - val_dice_coef: 0.5811 - val_iou: 0.4232 - val_recall: 0.8649 - val_precision: 0.6645 - lr: 1.0000e-05
# Epoch 10/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3933 - dice_coef: 0.6067 - iou: 0.4515 - recall: 0.9221 - precision: 0.7126
# Epoch 10: val_loss did not improve from 0.40786
# 160/160 [==============================] - 161s 1s/step - loss: 0.3933 - dice_coef: 0.6067 - iou: 0.4515 - recall: 0.9221 - precision: 0.7126 - val_loss: 0.4089 - val_dice_coef: 0.5911 - val_iou: 0.4354 - val_recall: 0.8448 - val_precision: 0.6904 - lr: 1.0000e-05
# Epoch 11/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3870 - dice_coef: 0.6130 - iou: 0.4576 - recall: 0.9188 - precision: 0.7241
# Epoch 11: val_loss improved from 0.40786 to 0.40599, saving model to files/model.h5
# 160/160 [==============================] - 168s 1s/step - loss: 0.3870 - dice_coef: 0.6130 - iou: 0.4576 - recall: 0.9188 - precision: 0.7241 - val_loss: 0.4060 - val_dice_coef: 0.5940 - val_iou: 0.4366 - val_recall: 0.8264 - val_precision: 0.6932 - lr: 1.0000e-05
# Epoch 12/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3958 - dice_coef: 0.6042 - iou: 0.4504 - recall: 0.9065 - precision: 0.7212
# Epoch 12: val_loss improved from 0.40599 to 0.40354, saving model to files/model.h5
# 160/160 [==============================] - 157s 983ms/step - loss: 0.3958 - dice_coef: 0.6042 - iou: 0.4504 - recall: 0.9065 - precision: 0.7212 - val_loss: 0.4035 - val_dice_coef: 0.5965 - val_iou: 0.4451 - val_recall: 0.8307 - val_precision: 0.6952 - lr: 1.0000e-05
# Epoch 13/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3677 - dice_coef: 0.6323 - iou: 0.4764 - recall: 0.9244 - precision: 0.7334
# Epoch 13: val_loss did not improve from 0.40354
# 160/160 [==============================] - 153s 954ms/step - loss: 0.3677 - dice_coef: 0.6323 - iou: 0.4764 - recall: 0.9244 - precision: 0.7334 - val_loss: 0.4174 - val_dice_coef: 0.5826 - val_iou: 0.4339 - val_recall: 0.8000 - val_precision: 0.7194 - lr: 1.0000e-05
# Epoch 14/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3641 - dice_coef: 0.6359 - iou: 0.4830 - recall: 0.9265 - precision: 0.7400
# Epoch 14: val_loss improved from 0.40354 to 0.40207, saving model to files/model.h5
# 160/160 [==============================] - 165s 1s/step - loss: 0.3641 - dice_coef: 0.6359 - iou: 0.4830 - recall: 0.9265 - precision: 0.7400 - val_loss: 0.4021 - val_dice_coef: 0.5979 - val_iou: 0.4476 - val_recall: 0.8095 - val_precision: 0.7046 - lr: 1.0000e-05
# Epoch 15/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3631 - dice_coef: 0.6369 - iou: 0.4873 - recall: 0.9233 - precision: 0.7376
# Epoch 15: val_loss improved from 0.40207 to 0.37968, saving model to files/model.h5
# 160/160 [==============================] - 155s 970ms/step - loss: 0.3631 - dice_coef: 0.6369 - iou: 0.4873 - recall: 0.9233 - precision: 0.7376 - val_loss: 0.3797 - val_dice_coef: 0.6203 - val_iou: 0.4655 - val_recall: 0.8187 - val_precision: 0.6970 - lr: 1.0000e-05
# Epoch 16/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3526 - dice_coef: 0.6474 - iou: 0.4970 - recall: 0.9375 - precision: 0.7452
# Epoch 16: val_loss did not improve from 0.37968
# 160/160 [==============================] - 161s 1s/step - loss: 0.3526 - dice_coef: 0.6474 - iou: 0.4970 - recall: 0.9375 - precision: 0.7452 - val_loss: 0.3976 - val_dice_coef: 0.6024 - val_iou: 0.4536 - val_recall: 0.7656 - val_precision: 0.7364 - lr: 1.0000e-05
# Epoch 17/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3480 - dice_coef: 0.6520 - iou: 0.5024 - recall: 0.9361 - precision: 0.7467
# Epoch 17: val_loss did not improve from 0.37968
# 160/160 [==============================] - 162s 1s/step - loss: 0.3480 - dice_coef: 0.6520 - iou: 0.5024 - recall: 0.9361 - precision: 0.7467 - val_loss: 0.3918 - val_dice_coef: 0.6082 - val_iou: 0.4562 - val_recall: 0.8063 - val_precision: 0.7137 - lr: 1.0000e-05
# Epoch 18/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3267 - dice_coef: 0.6733 - iou: 0.5250 - recall: 0.9393 - precision: 0.7573
# Epoch 18: val_loss did not improve from 0.37968
# 160/160 [==============================] - 153s 954ms/step - loss: 0.3267 - dice_coef: 0.6733 - iou: 0.5250 - recall: 0.9393 - precision: 0.7573 - val_loss: 0.3819 - val_dice_coef: 0.6181 - val_iou: 0.4645 - val_recall: 0.8109 - val_precision: 0.7023 - lr: 1.0000e-05
# Epoch 19/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3273 - dice_coef: 0.6727 - iou: 0.5210 - recall: 0.9359 - precision: 0.7584
# Epoch 19: val_loss did not improve from 0.37968
# 160/160 [==============================] - 152s 951ms/step - loss: 0.3273 - dice_coef: 0.6727 - iou: 0.5210 - recall: 0.9359 - precision: 0.7584 - val_loss: 0.3832 - val_dice_coef: 0.6168 - val_iou: 0.4656 - val_recall: 0.7731 - val_precision: 0.7366 - lr: 1.0000e-05
# Epoch 20/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3225 - dice_coef: 0.6775 - iou: 0.5301 - recall: 0.9409 - precision: 0.7618
# Epoch 20: val_loss improved from 0.37968 to 0.37221, saving model to files/model.h5
# 160/160 [==============================] - 157s 980ms/step - loss: 0.3225 - dice_coef: 0.6775 - iou: 0.5301 - recall: 0.9409 - precision: 0.7618 - val_loss: 0.3722 - val_dice_coef: 0.6278 - val_iou: 0.4806 - val_recall: 0.7907 - val_precision: 0.7225 - lr: 1.0000e-05

# %%
test_images = sorted(glob(os.path.join( "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Test/Image", "*")))
test_masks = sorted(glob(os.path.join( "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Test/Mask", "*")))

# %%
"""eval.py"""

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope      # used to implement additional metrics such as iou, dice_coef, etc

""" Directory for storing files """
create_dir("results")

results_dir = "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Semantic-Segmentation_Results/InceptionresNetV2/Results"

""" Loading model """# define functions that are externmal to tensorflow
with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
    model = tf.keras.models.load_model("files/model.h5")

for x, y in tqdm(zip(test_images, test_masks), total=len(test_images)):
        """ Extracing the image name. """
        image_name = x.split("/")[-1].split(".")[0]

        """ Reading the image """       # 'read_image' function
        ori_x = cv2.imread(x, cv2.IMREAD_COLOR)
        ori_x = cv2.resize(ori_x, (W, H))
        x = ori_x/255.0
        x = x.astype(np.float32)
        x = np.expand_dims(x, axis=0)


        """ Reading the mask """        # 'read_mask' function
        ori_y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        ori_y = cv2.resize(ori_y, (W, H))
        ori_y = np.expand_dims(ori_y, axis=-1)  ## (512, 512, 1)
        ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)  ## (512, 512, 3)

        """ Predicting the mask. """
        y_pred = model.predict(x)[0]> 0.5
        y_pred = y_pred.astype(np.int32)        # converting predicted result to integer datatype

        """ saving prediction in drive"""
        y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
        y_pred = y_pred*255

        """ Saving the predicted mask along with the image and GT """
        # save_image_path = f"results/{image_name}"   # location to save image
        save_image_path = f"{results_dir}/{image_name}.jpg"   # location to save image

        sep_line = np.ones((H, 10, 3)) * 255    # a white line with 10 pivel width
        cat_image = np.concatenate([ori_x, sep_line, ori_y, sep_line, y_pred], axis=1)  # original image | original mask | predicted mask [ori_x, sep_line, ori_y, sep_line, y_pred*255]

        cv2.imwrite(save_image_path, cat_image)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 1/1 [==============================] - 2s 2s/step
#   9%|▉         | 1/11 [00:02<00:27,  2.74s/it]
# 1/1 [==============================] - 0s 38ms/step
#  18%|█▊        | 2/11 [00:03<00:11,  1.31s/it]
# 1/1 [==============================] - 0s 36ms/step
#  27%|██▋       | 3/11 [00:03<00:06,  1.18it/s]
# 1/1 [==============================] - 0s 44ms/step
#  36%|███▋      | 4/11 [00:03<00:04,  1.64it/s]
# 1/1 [==============================] - 0s 35ms/step
#  45%|████▌     | 5/11 [00:03<00:03,  2.00it/s]
# 1/1 [==============================] - 0s 35ms/step
#  55%|█████▍    | 6/11 [00:04<00:02,  2.39it/s]
# 1/1 [==============================] - 0s 58ms/step
#  64%|██████▎   | 7/11 [00:04<00:01,  2.74it/s]
# 1/1 [==============================] - 0s 37ms/step
#  73%|███████▎  | 8/11 [00:04<00:00,  3.06it/s]
# 1/1 [==============================] - 0s 35ms/step
#  82%|████████▏ | 9/11 [00:04<00:00,  3.33it/s]
# 1/1 [==============================] - 0s 39ms/step
#  91%|█████████ | 10/11 [00:05<00:00,  3.29it/s]
# 1/1 [==============================] - 0s 44ms/step
# 100%|██████████| 11/11 [00:05<00:00,  2.01it/s]

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope      # used to implement additional metrics such as iou, dice_coef, etc

""" Function to create directory if it doesn't exist """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

""" Directory for storing files """
create_dir("results")

results_dir = "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Semantic-Segmentation_Results/InceptionresNetV2/Results"
pred_for_onionring = "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Semantic-Segmentation_Results/InceptionresNetV2/predictions_for_onionring"

""" Loading model """# define functions that are externmal to tensorflow
with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
    model = tf.keras.models.load_model("files/model.h5")


for x, y in tqdm(zip(test_images, test_masks), total=len(test_images)):
    """ Extracting the image name. """
    image_name = x.split("/")[-1].split(".")[0]

    """ Reading the image """       # 'read_image' function
    ori_x = cv2.imread(x, cv2.IMREAD_COLOR)
    ori_x = cv2.resize(ori_x, (W, H))
    x = ori_x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    """ Reading the mask """        # 'read_mask' function
    ori_y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    ori_y = cv2.resize(ori_y, (W, H))
    ori_y = np.expand_dims(ori_y, axis=-1)  ## (512, 512, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)  ## (512, 512, 3)

    """ Predicting the mask. """
    y_pred = model.predict(x)[0] > 0.5
    y_pred = y_pred.astype(np.int32)        # converting predicted result to integer datatype
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred*255

    """ Create a folder with the image name to store results """
    image_folder = os.path.join(results_dir, image_name)
    create_dir(image_folder)

    """ Saving the original image """
    ori_image_path = os.path.join(image_folder, f"org_{image_name}.jpg")
    cv2.imwrite(ori_image_path, ori_x)

    """ Saving the ground truth mask """
    gt_mask_path = os.path.join(image_folder, f"gt_{image_name}.jpg")
    cv2.imwrite(gt_mask_path, ori_y)

    """ Saving the predicted mask """
    pred_mask_path = os.path.join(image_folder, f"pred_{image_name}.jpg")
    pred_for_onionringseg = os.path.join(pred_for_onionring, f"{image_name}.jpg")
    # y_pred_visual = y_pred * 255
    cv2.imwrite(pred_mask_path, y_pred)
    cv2.imwrite(pred_for_onionringseg, y_pred) # for onion ring segmetation

    """ Saving the concatenated image """
    sep_line = np.ones((H, 10, 3)) * 255  # a white line with 10 pixel width
    cat_image = np.concatenate([ori_x, sep_line, ori_y, sep_line, y_pred], axis=1)
    montage_path = os.path.join(image_folder, f"montage_{image_name}.jpg")
    cv2.imwrite(montage_path, cat_image)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 1/1 [==============================] - 3s 3s/step
#   9%|▉         | 1/11 [00:03<00:34,  3.46s/it]
# 1/1 [==============================] - 0s 38ms/step
#  18%|█▊        | 2/11 [00:03<00:14,  1.60s/it]
# 1/1 [==============================] - 0s 37ms/step
#  27%|██▋       | 3/11 [00:04<00:08,  1.01s/it]
# 1/1 [==============================] - 0s 44ms/step
#  36%|███▋      | 4/11 [00:04<00:05,  1.37it/s]
# 1/1 [==============================] - 0s 37ms/step
#  45%|████▌     | 5/11 [00:04<00:03,  1.75it/s]
# 1/1 [==============================] - 0s 37ms/step
#  55%|█████▍    | 6/11 [00:04<00:02,  2.12it/s]
# 1/1 [==============================] - 0s 35ms/step
#  64%|██████▎   | 7/11 [00:05<00:01,  2.38it/s]
# 1/1 [==============================] - 0s 37ms/step
#  73%|███████▎  | 8/11 [00:05<00:01,  2.65it/s]
# 1/1 [==============================] - 0s 40ms/step
#  82%|████████▏ | 9/11 [00:05<00:00,  2.89it/s]
# 1/1 [==============================] - 0s 38ms/step
#  91%|█████████ | 10/11 [00:06<00:00,  3.08it/s]
# 1/1 [==============================] - 0s 49ms/step
# 100%|██████████| 11/11 [00:06<00:00,  1.72it/s]
