# %%
""" mount drive to access the dataset"""

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""model.py"""

from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

"""build_densenet50_unet is defined in'model' part of 'train.py'"""
# Out:
# "build_densenet50_unet is defined in'model' part of 'train.py'"

# %%
"""metric.py"""

import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
"""train.py"""

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau # ModelCheckPoint - save weights;
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision

""" Global parameters """
H = 512
W = 512

def create_dir(path):
    """ Create a directory. """
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(split=0.1): # split as 80-10-10 for train-val-test split
    images = sorted(glob(os.path.join( "/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Image", "*.jpg")))                       #
    masks = sorted(glob(os.path.join("/content/drive/MyDrive/Stanford-Computer_Vision-Rectina/Image_Dataset/Mask", "*.jpg")))        # EDIT ACCORDINGLY

    train_x, valid_x = train_test_split(images, test_size=split, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def apply_clahe_img(image):
    # Convert RGB image to LAB color space
    lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)

    # Apply CLAHE to the L channel (Lightness)
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    lab_planes[0] = clahe.apply(lab_planes[0])

    # Merge the enhanced L channel back with the other channels
    lab = cv2.merge(lab_planes)

    # Convert the LAB image back to RGB color space
    enhanced_image = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    return enhanced_image

def apply_clahe_mask(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    image = clahe.apply(image)
    return image

def read_image(path):       # read an image from train_x, or train_y, or... any other data split
    x = cv2.imread(path, cv2.IMREAD_COLOR)      # convert it to 3 channel (if grayscale or else colour only) and
    x = cv2.resize(x, (W, H))                   # resize image to (512,512,3)
    # x = apply_clahe_img(x)
    x = x/255.0                                 # normailise to have value bethween 0 and 1
    x = x.astype(np.float32)                    # convert to numpy float datatype
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    # x = apply_clahe_mask(x)
    x = x/np.max(x)
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)          # convert (512,512) to (512,512,1)
    return x

def tf_parse(x, y):        # this function takes in images x,y
    def _parse(x, y):      # calls read_image and read_mask on the image
        x = x.decode()
        y = y.decode()

        x = read_image(x)
        y = read_mask(y)
        return x, y             # returns as numpy array

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])     # converts numpy array to tensor type
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=8):     # Here X,Y are list containing the images
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.shuffle(buffer_size=200)  # shuffle the dataset
    dataset = dataset.map(tf_parse)     # calls 'tf_parse' function to convert to a tensor
    dataset = dataset.batch(batch)      # create a batch of data
    dataset = dataset.prefetch(4)       # prefect some data in advance to RAM
    return dataset

# %%
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)          # to ensure that randomness is prevented, simmillar results are produced at later implementations
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4      # to limit number of images eveluvated at once to handle GPU limitations
    lr = 1e-5           # learning rate
    num_epochs = 50     # number of iteations
    model_path = os.path.join("files", "model.h5")      # location where model weights from 'ModelCheckpoint' are stored
    csv_path = os.path.join("files", "data.csv")        # location where model csv details from 'CSVLogger' are stored

    """ Dataset """
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data()

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 47 - 47
# Valid: 6 - 6
# Test: 6 - 6

# %%
    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)   # create train and test dataset out of x_train and y_train
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
    """model"""

    def build_densenet121_unet(input_shape):

      """ Input """
      inputs = Input(input_shape)

      """ Pre-trained DenseNet121 Model """
      densenet = DenseNet121(include_top=False, weights="imagenet", input_tensor=inputs)

      """ Encoder """
      s1 = densenet.get_layer("input_1").output       ## 512
      s2 = densenet.get_layer("conv1/relu").output    ## 256
      s3 = densenet.get_layer("pool2_relu").output ## 128
      s4 = densenet.get_layer("pool3_relu").output  ## 64

      """ Bridge """
      b1 = densenet.get_layer("pool4_relu").output  ## 32

      """ Decoder """
      d1 = decoder_block(b1, s4, 512)             ## 64
      d2 = decoder_block(d1, s3, 256)             ## 128
      d3 = decoder_block(d2, s2, 128)             ## 256
      d4 = decoder_block(d3, s1, 64)              ## 512

      """ Outputs """
      outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

      model = Model(inputs, outputs)
      return model

    model = build_densenet121_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 518, 518, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 256, 256, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 256, 256, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 258, 258, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 128, 128, 64  0           ['zero_padding2d_1[0][0]']
#                                 )
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 64  256        ['pool1[0][0]']
#  ization)                       )
#
#  conv2_block1_0_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_0_bn[0][0]']
#  n)                             )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 12  8192        ['conv2_block1_0_relu[0][0]']
#                                 8)
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_concat (Concatena  (None, 128, 128, 96  0          ['pool1[0][0]',
#  te)                            )                                 'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 128, 128, 96  384        ['conv2_block1_concat[0][0]']
#  ization)                       )
#
#  conv2_block2_0_relu (Activatio  (None, 128, 128, 96  0          ['conv2_block2_0_bn[0][0]']
#  n)                             )
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 12  12288       ['conv2_block2_0_relu[0][0]']
#                                 8)
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_concat (Concatena  (None, 128, 128, 12  0          ['conv2_block1_concat[0][0]',
#  te)                            8)                                'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_concat[0][0]']
#  ization)                       8)
#
#  conv2_block3_0_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_0_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 12  16384       ['conv2_block3_0_relu[0][0]']
#                                 8)
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_concat (Concatena  (None, 128, 128, 16  0          ['conv2_block2_concat[0][0]',
#  te)                            0)                                'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 128, 128, 16  640        ['conv2_block3_concat[0][0]']
#  ization)                       0)
#
#  conv2_block4_0_relu (Activatio  (None, 128, 128, 16  0          ['conv2_block4_0_bn[0][0]']
#  n)                             0)
#
#  conv2_block4_1_conv (Conv2D)   (None, 128, 128, 12  20480       ['conv2_block4_0_relu[0][0]']
#                                 8)
#
#  conv2_block4_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block4_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block4_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block4_1_relu[0][0]']
#                                 )
#
#  conv2_block4_concat (Concatena  (None, 128, 128, 19  0          ['conv2_block3_concat[0][0]',
#  te)                            2)                                'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 128, 128, 19  768        ['conv2_block4_concat[0][0]']
#  ization)                       2)
#
#  conv2_block5_0_relu (Activatio  (None, 128, 128, 19  0          ['conv2_block5_0_bn[0][0]']
#  n)                             2)
#
#  conv2_block5_1_conv (Conv2D)   (None, 128, 128, 12  24576       ['conv2_block5_0_relu[0][0]']
#                                 8)
#
#  conv2_block5_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block5_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block5_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block5_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block5_1_relu[0][0]']
#                                 )
#
#  conv2_block5_concat (Concatena  (None, 128, 128, 22  0          ['conv2_block4_concat[0][0]',
#  te)                            4)                                'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 128, 128, 22  896        ['conv2_block5_concat[0][0]']
#  ization)                       4)
#
#  conv2_block6_0_relu (Activatio  (None, 128, 128, 22  0          ['conv2_block6_0_bn[0][0]']
#  n)                             4)
#
#  conv2_block6_1_conv (Conv2D)   (None, 128, 128, 12  28672       ['conv2_block6_0_relu[0][0]']
#                                 8)
#
#  conv2_block6_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block6_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block6_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block6_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block6_1_relu[0][0]']
#                                 )
#
#  conv2_block6_concat (Concatena  (None, 128, 128, 25  0          ['conv2_block5_concat[0][0]',
#  te)                            6)                                'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 128, 128, 25  1024        ['conv2_block6_concat[0][0]']
#                                 6)
#
#  pool2_relu (Activation)        (None, 128, 128, 25  0           ['pool2_bn[0][0]']
#                                 6)
#
#  pool2_conv (Conv2D)            (None, 128, 128, 12  32768       ['pool2_relu[0][0]']
#                                 8)
#
#  pool2_pool (AveragePooling2D)  (None, 64, 64, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 64, 64, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 64, 64, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 64, 64, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 64, 64, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 64, 64, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 64, 64, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 64, 64, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 64, 64, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 64, 64, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 64, 64, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 64, 64, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 64, 64, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 64, 64, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 64, 64, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 64, 64, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 64, 64, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 64, 64, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 64, 64, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 64, 64, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 64, 64, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 64, 64, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 64, 64, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 64, 64, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 64, 64, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 64, 64, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 64, 64, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 64, 64, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 64, 64, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 64, 64, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 64, 64, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 64, 64, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 64, 64, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 64, 64, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 64, 64, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 64, 64, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 64, 64, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 64, 64, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 64, 64, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 32, 32, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 32, 32, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 32, 32, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 32, 32, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 32, 32, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block5_1_bn[0][0]']
# ...
#
#  conv4_block22_0_bn (BatchNorma  (None, 32, 32, 928)  3712       ['conv4_block21_concat[0][0]']
#  lization)
#
#  conv4_block22_0_relu (Activati  (None, 32, 32, 928)  0          ['conv4_block22_0_bn[0][0]']
#  on)
#
#  conv4_block22_1_conv (Conv2D)  (None, 32, 32, 128)  118784      ['conv4_block22_0_relu[0][0]']
#
#  conv4_block22_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block22_1_conv[0][0]']
#  lization)
#
#  conv4_block22_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block22_1_relu[0][0]']
#
#  conv4_block22_concat (Concaten  (None, 32, 32, 960)  0          ['conv4_block21_concat[0][0]',
#  ate)                                                             'conv4_block22_2_conv[0][0]']
#
#  conv4_block23_0_bn (BatchNorma  (None, 32, 32, 960)  3840       ['conv4_block22_concat[0][0]']
#  lization)
#
#  conv4_block23_0_relu (Activati  (None, 32, 32, 960)  0          ['conv4_block23_0_bn[0][0]']
#  on)
#
#  conv4_block23_1_conv (Conv2D)  (None, 32, 32, 128)  122880      ['conv4_block23_0_relu[0][0]']
#
#  conv4_block23_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block23_1_relu[0][0]']
#
#  conv4_block23_concat (Concaten  (None, 32, 32, 992)  0          ['conv4_block22_concat[0][0]',
#  ate)                                                             'conv4_block23_2_conv[0][0]']
#
#  conv4_block24_0_bn (BatchNorma  (None, 32, 32, 992)  3968       ['conv4_block23_concat[0][0]']
#  lization)
#
#  conv4_block24_0_relu (Activati  (None, 32, 32, 992)  0          ['conv4_block24_0_bn[0][0]']
#  on)
#
#  conv4_block24_1_conv (Conv2D)  (None, 32, 32, 128)  126976      ['conv4_block24_0_relu[0][0]']
#
#  conv4_block24_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block24_1_conv[0][0]']
#  lization)
#
#  conv4_block24_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block24_1_bn[0][0]']
#  on)
#
#  conv4_block24_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block24_1_relu[0][0]']
#
#  conv4_block24_concat (Concaten  (None, 32, 32, 1024  0          ['conv4_block23_concat[0][0]',
#  ate)                           )                                 'conv4_block24_2_conv[0][0]']
#
#  pool4_bn (BatchNormalization)  (None, 32, 32, 1024  4096        ['conv4_block24_concat[0][0]']
#                                 )
#
#  pool4_relu (Activation)        (None, 32, 32, 1024  0           ['pool4_bn[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['pool4_relu[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'pool3_relu[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 64, 64, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_1[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'pool2_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  activation_2 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_2[0][0]']
#                                 6)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  590080      ['activation_2[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  rmalization)                   6)
#
#  activation_3 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_3[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_3[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 19  0           ['conv2d_transpose_2[0][0]',
#                                 2)                                'conv1/relu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  221312      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 67  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 512, 512, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 512, 512, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 1)  65          ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 16,410,241
# Trainable params: 16,352,961
# Non-trainable params: 57,280
# __________________________________________________________________________________________________

# %%
    # """Perform Data Augmentation on train and valid sets"""

    # import numpy as np
    # from keras.preprocessing.image import ImageDataGenerator
    # from skimage import io

    # datagen = ImageDataGenerator(
    #         rotation_range=45,     # Random rotation between 0 and 45
    #         width_shift_range=0.2,   # % shift
    #         height_shift_range=0.2,
    #         shear_range=0.2,
    #         zoom_range=0.2,
    #         horizontal_flip=True,
    #         fill_mode='nearest')

    # # Convert dataset objects to numpy arrays
    # train_images = np.array([train_x for train_x, _ in train_dataset])
    # train_labels = np.array([train_y for _, train_y in train_dataset])
    # valid_images = np.array([valid_x for valid_x, _ in valid_dataset])
    # valid_labels = np.array([valid_y for _, valid_y in valid_dataset])

    # # Generate augmented datasets using flow() method
    # augmented_train_dataset = datagen.flow(train_images, train_labels, batch_size=5)
    # augmented_valid_dataset = datagen.flow(valid_images, valid_labels, batch_size=5)

# %%
    callbacks = [                                                                  # defines callbacks
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path)
    ]

    model.fit(                                                                     # fits / trains data
            train_dataset,
            epochs=num_epochs,
            validation_data=valid_dataset,
            callbacks=callbacks
        )
# Out:
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8793 - dice_coef: 0.1195 - iou: 0.0644 - recall: 0.7525 - precision: 0.0701
# Epoch 1: val_loss improved from inf to 0.89877, saving model to files/model.h5
# 12/12 [==============================] - 171s 6s/step - loss: 0.8793 - dice_coef: 0.1195 - iou: 0.0644 - recall: 0.7525 - precision: 0.0701 - val_loss: 0.8988 - val_dice_coef: 0.0862 - val_iou: 0.0456 - val_recall: 0.9698 - val_precision: 0.0704 - lr: 1.0000e-05
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8513 - dice_coef: 0.1480 - iou: 0.0811 - recall: 0.8947 - precision: 0.0906
# Epoch 2: val_loss improved from 0.89877 to 0.89711, saving model to files/model.h5
# 12/12 [==============================] - 12s 961ms/step - loss: 0.8513 - dice_coef: 0.1480 - iou: 0.0811 - recall: 0.8947 - precision: 0.0906 - val_loss: 0.8971 - val_dice_coef: 0.0967 - val_iou: 0.0509 - val_recall: 0.6218 - val_precision: 0.0852 - lr: 1.0000e-05
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.8157 - dice_coef: 0.1841 - iou: 0.1033 - recall: 0.9693 - precision: 0.1221
# Epoch 3: val_loss improved from 0.89711 to 0.89709, saving model to files/model.h5
# 12/12 [==============================] - 12s 982ms/step - loss: 0.8157 - dice_coef: 0.1841 - iou: 0.1033 - recall: 0.9693 - precision: 0.1221 - val_loss: 0.8971 - val_dice_coef: 0.0967 - val_iou: 0.0509 - val_recall: 0.2843 - val_precision: 0.1153 - lr: 1.0000e-05
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7827 - dice_coef: 0.2147 - iou: 0.1224 - recall: 0.9876 - precision: 0.1828
# Epoch 4: val_loss improved from 0.89709 to 0.89684, saving model to files/model.h5
# 12/12 [==============================] - 12s 964ms/step - loss: 0.7827 - dice_coef: 0.2147 - iou: 0.1224 - recall: 0.9876 - precision: 0.1828 - val_loss: 0.8968 - val_dice_coef: 0.0986 - val_iou: 0.0519 - val_recall: 0.1173 - val_precision: 0.1514 - lr: 1.0000e-05
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7629 - dice_coef: 0.2351 - iou: 0.1381 - recall: 0.9850 - precision: 0.2698
# Epoch 5: val_loss did not improve from 0.89684
# 12/12 [==============================] - 10s 833ms/step - loss: 0.7629 - dice_coef: 0.2351 - iou: 0.1381 - recall: 0.9850 - precision: 0.2698 - val_loss: 0.9027 - val_dice_coef: 0.1213 - val_iou: 0.0661 - val_recall: 0.0504 - val_precision: 0.2031 - lr: 1.0000e-05
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7357 - dice_coef: 0.2595 - iou: 0.1551 - recall: 0.9878 - precision: 0.3343
# Epoch 6: val_loss did not improve from 0.89684
# 12/12 [==============================] - 11s 858ms/step - loss: 0.7357 - dice_coef: 0.2595 - iou: 0.1551 - recall: 0.9878 - precision: 0.3343 - val_loss: 0.8970 - val_dice_coef: 0.0986 - val_iou: 0.0519 - val_recall: 0.0212 - val_precision: 0.3389 - lr: 1.0000e-05
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7111 - dice_coef: 0.2922 - iou: 0.1766 - recall: 0.9899 - precision: 0.3692
# Epoch 7: val_loss did not improve from 0.89684
# 12/12 [==============================] - 10s 844ms/step - loss: 0.7111 - dice_coef: 0.2922 - iou: 0.1766 - recall: 0.9899 - precision: 0.3692 - val_loss: 0.8998 - val_dice_coef: 0.1180 - val_iou: 0.0635 - val_recall: 0.0101 - val_precision: 0.6681 - lr: 1.0000e-05
# Epoch 8/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6912 - dice_coef: 0.3080 - iou: 0.1908 - recall: 0.9882 - precision: 0.4009
# Epoch 8: val_loss did not improve from 0.89684
# 12/12 [==============================] - 11s 883ms/step - loss: 0.6912 - dice_coef: 0.3080 - iou: 0.1908 - recall: 0.9882 - precision: 0.4009 - val_loss: 0.8975 - val_dice_coef: 0.0940 - val_iou: 0.0495 - val_recall: 0.0074 - val_precision: 0.8870 - lr: 1.0000e-05
# Epoch 9/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6610 - dice_coef: 0.3380 - iou: 0.2104 - recall: 0.9913 - precision: 0.4378
# Epoch 9: val_loss improved from 0.89684 to 0.89604, saving model to files/model.h5
# 12/12 [==============================] - 11s 923ms/step - loss: 0.6610 - dice_coef: 0.3380 - iou: 0.2104 - recall: 0.9913 - precision: 0.4378 - val_loss: 0.8960 - val_dice_coef: 0.1025 - val_iou: 0.0540 - val_recall: 0.0174 - val_precision: 0.9873 - lr: 1.0000e-05
# Epoch 10/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6351 - dice_coef: 0.3608 - iou: 0.2284 - recall: 0.9918 - precision: 0.4838
# Epoch 10: val_loss improved from 0.89604 to 0.89460, saving model to files/model.h5
# 12/12 [==============================] - 12s 970ms/step - loss: 0.6351 - dice_coef: 0.3608 - iou: 0.2284 - recall: 0.9918 - precision: 0.4838 - val_loss: 0.8946 - val_dice_coef: 0.1045 - val_iou: 0.0552 - val_recall: 0.0314 - val_precision: 0.9989 - lr: 1.0000e-05
# Epoch 11/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6230 - dice_coef: 0.3777 - iou: 0.2431 - recall: 0.9847 - precision: 0.5109
# Epoch 11: val_loss improved from 0.89460 to 0.89257, saving model to files/model.h5
# 12/12 [==============================] - 11s 910ms/step - loss: 0.6230 - dice_coef: 0.3777 - iou: 0.2431 - recall: 0.9847 - precision: 0.5109 - val_loss: 0.8926 - val_dice_coef: 0.1098 - val_iou: 0.0581 - val_recall: 0.0449 - val_precision: 0.9995 - lr: 1.0000e-05
# Epoch 12/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6166 - dice_coef: 0.3827 - iou: 0.2522 - recall: 0.9751 - precision: 0.5341
# Epoch 12: val_loss did not improve from 0.89257
# 12/12 [==============================] - 11s 848ms/step - loss: 0.6166 - dice_coef: 0.3827 - iou: 0.2522 - recall: 0.9751 - precision: 0.5341 - val_loss: 0.8930 - val_dice_coef: 0.0915 - val_iou: 0.0486 - val_recall: 0.0607 - val_precision: 0.9994 - lr: 1.0000e-05
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5800 - dice_coef: 0.4232 - iou: 0.2792 - recall: 0.9885 - precision: 0.5761
# Epoch 13: val_loss improved from 0.89257 to 0.88806, saving model to files/model.h5
# 12/12 [==============================] - 12s 953ms/step - loss: 0.5800 - dice_coef: 0.4232 - iou: 0.2792 - recall: 0.9885 - precision: 0.5761 - val_loss: 0.8881 - val_dice_coef: 0.1057 - val_iou: 0.0559 - val_recall: 0.0809 - val_precision: 0.9981 - lr: 1.0000e-05
# Epoch 14/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5504 - dice_coef: 0.4525 - iou: 0.2991 - recall: 0.9879 - precision: 0.6201
# Epoch 14: val_loss improved from 0.88806 to 0.88469, saving model to files/model.h5
# 12/12 [==============================] - 12s 965ms/step - loss: 0.5504 - dice_coef: 0.4525 - iou: 0.2991 - recall: 0.9879 - precision: 0.6201 - val_loss: 0.8847 - val_dice_coef: 0.1146 - val_iou: 0.0608 - val_recall: 0.0917 - val_precision: 0.9956 - lr: 1.0000e-05
# Epoch 15/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5755 - dice_coef: 0.4278 - iou: 0.2913 - recall: 0.9699 - precision: 0.6268
# Epoch 15: val_loss did not improve from 0.88469
# 12/12 [==============================] - 11s 881ms/step - loss: 0.5755 - dice_coef: 0.4278 - iou: 0.2913 - recall: 0.9699 - precision: 0.6268 - val_loss: 0.8849 - val_dice_coef: 0.1068 - val_iou: 0.0566 - val_recall: 0.0920 - val_precision: 0.9953 - lr: 1.0000e-05
# Epoch 16/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5346 - dice_coef: 0.4693 - iou: 0.3192 - recall: 0.9825 - precision: 0.6723
# Epoch 16: val_loss did not improve from 0.88469
# 12/12 [==============================] - 10s 834ms/step - loss: 0.5346 - dice_coef: 0.4693 - iou: 0.3192 - recall: 0.9825 - precision: 0.6723 - val_loss: 0.8867 - val_dice_coef: 0.1270 - val_iou: 0.0683 - val_recall: 0.0929 - val_precision: 0.9943 - lr: 1.0000e-05
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5214 - dice_coef: 0.4762 - iou: 0.3246 - recall: 0.9767 - precision: 0.7181
# Epoch 17: val_loss improved from 0.88469 to 0.87730, saving model to files/model.h5
# 12/12 [==============================] - 12s 977ms/step - loss: 0.5214 - dice_coef: 0.4762 - iou: 0.3246 - recall: 0.9767 - precision: 0.7181 - val_loss: 0.8773 - val_dice_coef: 0.1240 - val_iou: 0.0661 - val_recall: 0.1113 - val_precision: 0.9905 - lr: 1.0000e-05
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5107 - dice_coef: 0.4845 - iou: 0.3329 - recall: 0.9761 - precision: 0.7256
# Epoch 18: val_loss improved from 0.87730 to 0.86409, saving model to files/model.h5
# 12/12 [==============================] - 11s 928ms/step - loss: 0.5107 - dice_coef: 0.4845 - iou: 0.3329 - recall: 0.9761 - precision: 0.7256 - val_loss: 0.8641 - val_dice_coef: 0.1326 - val_iou: 0.0711 - val_recall: 0.1486 - val_precision: 0.9843 - lr: 1.0000e-05
# Epoch 19/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5211 - dice_coef: 0.4796 - iou: 0.3321 - recall: 0.9718 - precision: 0.7267
# Epoch 19: val_loss did not improve from 0.86409
# 12/12 [==============================] - 11s 860ms/step - loss: 0.5211 - dice_coef: 0.4796 - iou: 0.3321 - recall: 0.9718 - precision: 0.7267 - val_loss: 0.8702 - val_dice_coef: 0.1416 - val_iou: 0.0766 - val_recall: 0.1357 - val_precision: 0.9858 - lr: 1.0000e-05
# Epoch 20/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5025 - dice_coef: 0.4988 - iou: 0.3476 - recall: 0.9734 - precision: 0.7528
# Epoch 20: val_loss did not improve from 0.86409
# 12/12 [==============================] - 10s 860ms/step - loss: 0.5025 - dice_coef: 0.4988 - iou: 0.3476 - recall: 0.9734 - precision: 0.7528 - val_loss: 0.8680 - val_dice_coef: 0.1231 - val_iou: 0.0658 - val_recall: 0.1305 - val_precision: 0.9861 - lr: 1.0000e-05
# Epoch 21/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4968 - dice_coef: 0.5036 - iou: 0.3486 - recall: 0.9612 - precision: 0.7700
# Epoch 21: val_loss did not improve from 0.86409
# 12/12 [==============================] - 11s 877ms/step - loss: 0.4968 - dice_coef: 0.5036 - iou: 0.3486 - recall: 0.9612 - precision: 0.7700 - val_loss: 0.8733 - val_dice_coef: 0.1120 - val_iou: 0.0599 - val_recall: 0.1195 - val_precision: 0.9863 - lr: 1.0000e-05
# Epoch 22/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4901 - dice_coef: 0.5129 - iou: 0.3601 - recall: 0.9709 - precision: 0.7912
# Epoch 22: val_loss did not improve from 0.86409
# 12/12 [==============================] - 11s 868ms/step - loss: 0.4901 - dice_coef: 0.5129 - iou: 0.3601 - recall: 0.9709 - precision: 0.7912 - val_loss: 0.8663 - val_dice_coef: 0.1338 - val_iou: 0.0717 - val_recall: 0.1207 - val_precision: 0.9875 - lr: 1.0000e-05
# Epoch 23/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4731 - dice_coef: 0.5209 - iou: 0.3658 - recall: 0.9785 - precision: 0.7949
# Epoch 23: val_loss did not improve from 0.86409
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 12/12 [==============================] - 10s 859ms/step - loss: 0.4731 - dice_coef: 0.5209 - iou: 0.3658 - recall: 0.9785 - precision: 0.7949 - val_loss: 0.8783 - val_dice_coef: 0.1120 - val_iou: 0.0595 - val_recall: 0.0956 - val_precision: 0.9921 - lr: 1.0000e-05
# Epoch 24/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4863 - dice_coef: 0.5090 - iou: 0.3576 - recall: 0.9715 - precision: 0.8092
# Epoch 24: val_loss did not improve from 0.86409
# 12/12 [==============================] - 10s 820ms/step - loss: 0.4863 - dice_coef: 0.5090 - iou: 0.3576 - recall: 0.9715 - precision: 0.8092 - val_loss: 0.8712 - val_dice_coef: 0.1263 - val_iou: 0.0674 - val_recall: 0.1015 - val_precision: 0.9914 - lr: 1.0000e-06
# Epoch 25/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4799 - dice_coef: 0.5208 - iou: 0.3653 - recall: 0.9719 - precision: 0.7988
# Epoch 25: val_loss did not improve from 0.86409
# 12/12 [==============================] - 11s 858ms/step - loss: 0.4799 - dice_coef: 0.5208 - iou: 0.3653 - recall: 0.9719 - precision: 0.7988 - val_loss: 0.8665 - val_dice_coef: 0.1394 - val_iou: 0.0750 - val_recall: 0.1105 - val_precision: 0.9906 - lr: 1.0000e-06
# Epoch 26/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4805 - dice_coef: 0.5194 - iou: 0.3664 - recall: 0.9715 - precision: 0.7979
# Epoch 26: val_loss improved from 0.86409 to 0.86000, saving model to files/model.h5
# 12/12 [==============================] - 12s 972ms/step - loss: 0.4805 - dice_coef: 0.5194 - iou: 0.3664 - recall: 0.9715 - precision: 0.7979 - val_loss: 0.8600 - val_dice_coef: 0.1347 - val_iou: 0.0723 - val_recall: 0.1188 - val_precision: 0.9888 - lr: 1.0000e-06
# Epoch 27/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4655 - dice_coef: 0.5371 - iou: 0.3801 - recall: 0.9800 - precision: 0.8076
# Epoch 27: val_loss did not improve from 0.86000
# 12/12 [==============================] - 11s 852ms/step - loss: 0.4655 - dice_coef: 0.5371 - iou: 0.3801 - recall: 0.9800 - precision: 0.8076 - val_loss: 0.8666 - val_dice_coef: 0.1111 - val_iou: 0.0601 - val_recall: 0.1286 - val_precision: 0.9872 - lr: 1.0000e-06
# Epoch 28/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4535 - dice_coef: 0.5456 - iou: 0.3828 - recall: 0.9828 - precision: 0.8134
# Epoch 28: val_loss improved from 0.86000 to 0.84619, saving model to files/model.h5
# 12/12 [==============================] - 11s 945ms/step - loss: 0.4535 - dice_coef: 0.5456 - iou: 0.3828 - recall: 0.9828 - precision: 0.8134 - val_loss: 0.8462 - val_dice_coef: 0.1401 - val_iou: 0.0759 - val_recall: 0.1386 - val_precision: 0.9847 - lr: 1.0000e-06
# Epoch 29/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4902 - dice_coef: 0.5158 - iou: 0.3663 - recall: 0.9669 - precision: 0.8034
# Epoch 29: val_loss improved from 0.84619 to 0.84117, saving model to files/model.h5
# 12/12 [==============================] - 12s 995ms/step - loss: 0.4902 - dice_coef: 0.5158 - iou: 0.3663 - recall: 0.9669 - precision: 0.8034 - val_loss: 0.8412 - val_dice_coef: 0.1528 - val_iou: 0.0828 - val_recall: 0.1568 - val_precision: 0.9805 - lr: 1.0000e-06
# Epoch 30/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4674 - dice_coef: 0.5286 - iou: 0.3723 - recall: 0.9811 - precision: 0.8143
# Epoch 30: val_loss improved from 0.84117 to 0.82874, saving model to files/model.h5
# 12/12 [==============================] - 12s 1s/step - loss: 0.4674 - dice_coef: 0.5286 - iou: 0.3723 - recall: 0.9811 - precision: 0.8143 - val_loss: 0.8287 - val_dice_coef: 0.1651 - val_iou: 0.0901 - val_recall: 0.1785 - val_precision: 0.9729 - lr: 1.0000e-06
# Epoch 31/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4659 - dice_coef: 0.5343 - iou: 0.3765 - recall: 0.9799 - precision: 0.8125
# Epoch 31: val_loss improved from 0.82874 to 0.82332, saving model to files/model.h5
# 12/12 [==============================] - 12s 955ms/step - loss: 0.4659 - dice_coef: 0.5343 - iou: 0.3765 - recall: 0.9799 - precision: 0.8125 - val_loss: 0.8233 - val_dice_coef: 0.1615 - val_iou: 0.0885 - val_recall: 0.1956 - val_precision: 0.9660 - lr: 1.0000e-06
# Epoch 32/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4667 - dice_coef: 0.5369 - iou: 0.3806 - recall: 0.9774 - precision: 0.8169
# Epoch 32: val_loss improved from 0.82332 to 0.81316, saving model to files/model.h5
# 12/12 [==============================] - 12s 1s/step - loss: 0.4667 - dice_coef: 0.5369 - iou: 0.3806 - recall: 0.9774 - precision: 0.8169 - val_loss: 0.8132 - val_dice_coef: 0.1712 - val_iou: 0.0943 - val_recall: 0.2121 - val_precision: 0.9593 - lr: 1.0000e-06
# Epoch 33/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4965 - dice_coef: 0.5060 - iou: 0.3602 - recall: 0.9655 - precision: 0.8008
# Epoch 33: val_loss improved from 0.81316 to 0.79561, saving model to files/model.h5
# 12/12 [==============================] - 11s 933ms/step - loss: 0.4965 - dice_coef: 0.5060 - iou: 0.3602 - recall: 0.9655 - precision: 0.8008 - val_loss: 0.7956 - val_dice_coef: 0.2346 - val_iou: 0.1358 - val_recall: 0.2378 - val_precision: 0.9542 - lr: 1.0000e-06
# Epoch 34/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4908 - dice_coef: 0.5086 - iou: 0.3628 - recall: 0.9730 - precision: 0.7884
# Epoch 34: val_loss improved from 0.79561 to 0.77223, saving model to files/model.h5
# 12/12 [==============================] - 12s 984ms/step - loss: 0.4908 - dice_coef: 0.5086 - iou: 0.3628 - recall: 0.9730 - precision: 0.7884 - val_loss: 0.7722 - val_dice_coef: 0.2237 - val_iou: 0.1260 - val_recall: 0.2723 - val_precision: 0.9447 - lr: 1.0000e-06
# Epoch 35/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4867 - dice_coef: 0.5135 - iou: 0.3604 - recall: 0.9641 - precision: 0.7976
# Epoch 35: val_loss improved from 0.77223 to 0.75566, saving model to files/model.h5
# 12/12 [==============================] - 12s 1s/step - loss: 0.4867 - dice_coef: 0.5135 - iou: 0.3604 - recall: 0.9641 - precision: 0.7976 - val_loss: 0.7557 - val_dice_coef: 0.2525 - val_iou: 0.1447 - val_recall: 0.2984 - val_precision: 0.9395 - lr: 1.0000e-06
# Epoch 36/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4867 - dice_coef: 0.5139 - iou: 0.3655 - recall: 0.9690 - precision: 0.8046
# Epoch 36: val_loss improved from 0.75566 to 0.74699, saving model to files/model.h5
# 12/12 [==============================] - 12s 950ms/step - loss: 0.4867 - dice_coef: 0.5139 - iou: 0.3655 - recall: 0.9690 - precision: 0.8046 - val_loss: 0.7470 - val_dice_coef: 0.2916 - val_iou: 0.1761 - val_recall: 0.3327 - val_precision: 0.9296 - lr: 1.0000e-06
# Epoch 37/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4668 - dice_coef: 0.5334 - iou: 0.3765 - recall: 0.9752 - precision: 0.8193
# Epoch 37: val_loss improved from 0.74699 to 0.72191, saving model to files/model.h5
# 12/12 [==============================] - 12s 991ms/step - loss: 0.4668 - dice_coef: 0.5334 - iou: 0.3765 - recall: 0.9752 - precision: 0.8193 - val_loss: 0.7219 - val_dice_coef: 0.2474 - val_iou: 0.1443 - val_recall: 0.3506 - val_precision: 0.9223 - lr: 1.0000e-06
# Epoch 38/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4750 - dice_coef: 0.5212 - iou: 0.3690 - recall: 0.9786 - precision: 0.8089
# Epoch 38: val_loss did not improve from 0.72191
# 12/12 [==============================] - 10s 796ms/step - loss: 0.4750 - dice_coef: 0.5212 - iou: 0.3690 - recall: 0.9786 - precision: 0.8089 - val_loss: 0.7307 - val_dice_coef: 0.2466 - val_iou: 0.1424 - val_recall: 0.3681 - val_precision: 0.9123 - lr: 1.0000e-06
# Epoch 39/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4783 - dice_coef: 0.5180 - iou: 0.3650 - recall: 0.9759 - precision: 0.8081
# Epoch 39: val_loss did not improve from 0.72191
# 12/12 [==============================] - 10s 797ms/step - loss: 0.4783 - dice_coef: 0.5180 - iou: 0.3650 - recall: 0.9759 - precision: 0.8081 - val_loss: 0.7234 - val_dice_coef: 0.2965 - val_iou: 0.1755 - val_recall: 0.3870 - val_precision: 0.9029 - lr: 1.0000e-06
# Epoch 40/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4731 - dice_coef: 0.5240 - iou: 0.3662 - recall: 0.9589 - precision: 0.8181
# Epoch 40: val_loss improved from 0.72191 to 0.70198, saving model to files/model.h5
# 12/12 [==============================] - 12s 991ms/step - loss: 0.4731 - dice_coef: 0.5240 - iou: 0.3662 - recall: 0.9589 - precision: 0.8181 - val_loss: 0.7020 - val_dice_coef: 0.2870 - val_iou: 0.1680 - val_recall: 0.4021 - val_precision: 0.8942 - lr: 1.0000e-06
# Epoch 41/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4682 - dice_coef: 0.5306 - iou: 0.3761 - recall: 0.9750 - precision: 0.8222
# Epoch 41: val_loss improved from 0.70198 to 0.68746, saving model to files/model.h5
# 12/12 [==============================] - 11s 947ms/step - loss: 0.4682 - dice_coef: 0.5306 - iou: 0.3761 - recall: 0.9750 - precision: 0.8222 - val_loss: 0.6875 - val_dice_coef: 0.3240 - val_iou: 0.1938 - val_recall: 0.4156 - val_precision: 0.8856 - lr: 1.0000e-06
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4728 - dice_coef: 0.5292 - iou: 0.3754 - recall: 0.9751 - precision: 0.8188
# Epoch 42: val_loss improved from 0.68746 to 0.67471, saving model to files/model.h5
# 12/12 [==============================] - 11s 908ms/step - loss: 0.4728 - dice_coef: 0.5292 - iou: 0.3754 - recall: 0.9751 - precision: 0.8188 - val_loss: 0.6747 - val_dice_coef: 0.3036 - val_iou: 0.1807 - val_recall: 0.4321 - val_precision: 0.8790 - lr: 1.0000e-06
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4797 - dice_coef: 0.5182 - iou: 0.3653 - recall: 0.9671 - precision: 0.8146
# Epoch 43: val_loss improved from 0.67471 to 0.67307, saving model to files/model.h5
# 12/12 [==============================] - 11s 915ms/step - loss: 0.4797 - dice_coef: 0.5182 - iou: 0.3653 - recall: 0.9671 - precision: 0.8146 - val_loss: 0.6731 - val_dice_coef: 0.3542 - val_iou: 0.2182 - val_recall: 0.4437 - val_precision: 0.8761 - lr: 1.0000e-06
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4578 - dice_coef: 0.5453 - iou: 0.3867 - recall: 0.9808 - precision: 0.8206
# Epoch 44: val_loss did not improve from 0.67307
# 12/12 [==============================] - 10s 799ms/step - loss: 0.4578 - dice_coef: 0.5453 - iou: 0.3867 - recall: 0.9808 - precision: 0.8206 - val_loss: 0.6870 - val_dice_coef: 0.3361 - val_iou: 0.2041 - val_recall: 0.4554 - val_precision: 0.8722 - lr: 1.0000e-06
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4817 - dice_coef: 0.5174 - iou: 0.3644 - recall: 0.9641 - precision: 0.8136
# Epoch 45: val_loss did not improve from 0.67307
# 12/12 [==============================] - 10s 854ms/step - loss: 0.4817 - dice_coef: 0.5174 - iou: 0.3644 - recall: 0.9641 - precision: 0.8136 - val_loss: 0.6736 - val_dice_coef: 0.2958 - val_iou: 0.1770 - val_recall: 0.4818 - val_precision: 0.8633 - lr: 1.0000e-06
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4502 - dice_coef: 0.5468 - iou: 0.3850 - recall: 0.9800 - precision: 0.8303
# Epoch 46: val_loss improved from 0.67307 to 0.64214, saving model to files/model.h5
# 12/12 [==============================] - 11s 927ms/step - loss: 0.4502 - dice_coef: 0.5468 - iou: 0.3850 - recall: 0.9800 - precision: 0.8303 - val_loss: 0.6421 - val_dice_coef: 0.3672 - val_iou: 0.2253 - val_recall: 0.5008 - val_precision: 0.8573 - lr: 1.0000e-06
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4667 - dice_coef: 0.5343 - iou: 0.3801 - recall: 0.9773 - precision: 0.8290
# Epoch 47: val_loss did not improve from 0.64214
# 12/12 [==============================] - 10s 858ms/step - loss: 0.4667 - dice_coef: 0.5343 - iou: 0.3801 - recall: 0.9773 - precision: 0.8290 - val_loss: 0.6611 - val_dice_coef: 0.3663 - val_iou: 0.2273 - val_recall: 0.5177 - val_precision: 0.8501 - lr: 1.0000e-06
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4627 - dice_coef: 0.5384 - iou: 0.3834 - recall: 0.9784 - precision: 0.8275
# Epoch 48: val_loss improved from 0.64214 to 0.63086, saving model to files/model.h5
# 12/12 [==============================] - 11s 912ms/step - loss: 0.4627 - dice_coef: 0.5384 - iou: 0.3834 - recall: 0.9784 - precision: 0.8275 - val_loss: 0.6309 - val_dice_coef: 0.3306 - val_iou: 0.2038 - val_recall: 0.5297 - val_precision: 0.8448 - lr: 1.0000e-06
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4772 - dice_coef: 0.5208 - iou: 0.3633 - recall: 0.9560 - precision: 0.8148
# Epoch 49: val_loss did not improve from 0.63086
# 12/12 [==============================] - 10s 819ms/step - loss: 0.4772 - dice_coef: 0.5208 - iou: 0.3633 - recall: 0.9560 - precision: 0.8148 - val_loss: 0.6333 - val_dice_coef: 0.4067 - val_iou: 0.2625 - val_recall: 0.5436 - val_precision: 0.8390 - lr: 1.0000e-06
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4429 - dice_coef: 0.5573 - iou: 0.3932 - recall: 0.9818 - precision: 0.8319
# Epoch 50: val_loss improved from 0.63086 to 0.62174, saving model to files/model.h5
# 12/12 [==============================] - 12s 987ms/step - loss: 0.4429 - dice_coef: 0.5573 - iou: 0.3932 - recall: 0.9818 - precision: 0.8319 - val_loss: 0.6217 - val_dice_coef: 0.3663 - val_iou: 0.2248 - val_recall: 0.5587 - val_precision: 0.8308 - lr: 1.0000e-06

# %%
"""eval.py"""

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope      # used to implement additional metrics such as iou, dice_coef, etc

""" Directory for storing files """
create_dir("results")

""" Loading model """# define functions that are externmal to tensorflow
with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
    model = tf.keras.models.load_model("files/model.h5")

for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extracing the image name. """
        image_name = x.split("/")[-1]

        """ Reading the image """       # 'read_image' function
        ori_x = cv2.imread(x, cv2.IMREAD_COLOR)
        ori_x = cv2.resize(ori_x, (W, H))
        x = ori_x/255.0
        x = x.astype(np.float32)
        x = np.expand_dims(x, axis=0)

        """ Reading the mask """        # 'read_mask' function
        ori_y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        ori_y = cv2.resize(ori_y, (W, H))
        ori_y = np.expand_dims(ori_y, axis=-1)  ## (512, 512, 1)
        ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)  ## (512, 512, 3)

        """ Predicting the mask. """
        y_pred = model.predict(x)[0]> 0.5
        y_pred = y_pred.astype(np.int32)        # converting predicted result to integer datatype

        y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)

        """ Saving the predicted mask along with the image and GT """
        save_image_path = f"results/{image_name}"   # location to save image

        sep_line = np.ones((H, 10, 3)) * 255    # a white line with 10 pivel width

        cat_image = np.concatenate([ori_x, sep_line, ori_y, sep_line, y_pred*255], axis=1)  # original image | original mask | predicted mask [ori_x, sep_line, ori_y, sep_line, y_pred*255]

        cv2.imwrite(save_image_path, cat_image)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# 1/1 [==============================] - 2s 2s/step
#  17%|█▋        | 1/6 [00:02<00:11,  2.35s/it]
# 1/1 [==============================] - 0s 41ms/step
#  33%|███▎      | 2/6 [00:02<00:04,  1.19s/it]
# 1/1 [==============================] - 0s 27ms/step
#  50%|█████     | 3/6 [00:02<00:02,  1.33it/s]
# 1/1 [==============================] - 0s 27ms/step
#  67%|██████▋   | 4/6 [00:03<00:01,  1.75it/s]
# 1/1 [==============================] - 0s 30ms/step
#  83%|████████▎ | 5/6 [00:03<00:00,  2.22it/s]
# 1/1 [==============================] - 0s 29ms/step
# 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
